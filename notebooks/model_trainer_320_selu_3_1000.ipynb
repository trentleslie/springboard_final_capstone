# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(4, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 320

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 25

LAYER_ACTIVATION = "selu"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

with tf.device('/device:GPU:0'):
    history = model.fit(X_train, y_train,
                        batch_size=BATCH_SIZE,
                        epochs=EPOCHS,
                        validation_data=(X_test, y_test),
                        callbacks=[checkpointer, tensorboard],
                        verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 61009 samples, validate on 26148 samples
# Epoch 1/25
# 60928/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00001: val_loss improved from inf to 0.31771, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 49s 806us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.3177 - val_mean_absolute_error: 0.6438
# Epoch 2/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00002: val_loss improved from 0.31771 to 0.28973, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 647us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2897 - val_mean_absolute_error: 0.6076
# Epoch 3/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00003: val_loss improved from 0.28973 to 0.26602, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2660 - val_mean_absolute_error: 0.5749
# Epoch 4/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.2069 - mean_absolute_error: 0.4946
# Epoch 00004: val_loss improved from 0.26602 to 0.25461, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 627us/sample - loss: 0.2069 - mean_absolute_error: 0.4946 - val_loss: 0.2546 - val_mean_absolute_error: 0.5594
# Epoch 5/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00005: val_loss improved from 0.25461 to 0.25099, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 629us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2510 - val_mean_absolute_error: 0.5538
# Epoch 6/25
# 60928/61009 [============================>.] - ETA: 0s - loss: 0.1699 - mean_absolute_error: 0.4404
# Epoch 00006: val_loss improved from 0.25099 to 0.24220, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: 0.1699 - mean_absolute_error: 0.4404 - val_loss: 0.2422 - val_mean_absolute_error: 0.5416
# Epoch 7/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1587 - mean_absolute_error: 0.4232
# Epoch 00007: val_loss improved from 0.24220 to 0.23963, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: 0.1586 - mean_absolute_error: 0.4232 - val_loss: 0.2396 - val_mean_absolute_error: 0.5375
# Epoch 8/25
# 60928/61009 [============================>.] - ETA: 0s - loss: 0.1516 - mean_absolute_error: 0.4126
# Epoch 00008: val_loss improved from 0.23963 to 0.23823, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: 0.1517 - mean_absolute_error: 0.4127 - val_loss: 0.2382 - val_mean_absolute_error: 0.5355
# Epoch 9/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00009: val_loss improved from 0.23823 to 0.23515, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 635us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2351 - val_mean_absolute_error: 0.5306
# Epoch 10/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1378 - mean_absolute_error: 0.3899
# Epoch 00010: val_loss improved from 0.23515 to 0.23222, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 630us/sample - loss: 0.1379 - mean_absolute_error: 0.3900 - val_loss: 0.2322 - val_mean_absolute_error: 0.5267
# Epoch 11/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1330 - mean_absolute_error: 0.3822
# Epoch 00011: val_loss improved from 0.23222 to 0.22994, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 627us/sample - loss: 0.1330 - mean_absolute_error: 0.3822 - val_loss: 0.2299 - val_mean_absolute_error: 0.5223
# Epoch 12/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1285 - mean_absolute_error: 0.3743
# Epoch 00012: val_loss did not improve from 0.22994
# 61009/61009 [==============================] - 38s 621us/sample - loss: 0.1285 - mean_absolute_error: 0.3742 - val_loss: 0.2306 - val_mean_absolute_error: 0.5228
# Epoch 13/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1251 - mean_absolute_error: 0.3684
# Epoch 00013: val_loss improved from 0.22994 to 0.22820, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 628us/sample - loss: 0.1251 - mean_absolute_error: 0.3684 - val_loss: 0.2282 - val_mean_absolute_error: 0.5191
# Epoch 14/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1215 - mean_absolute_error: 0.3625
# Epoch 00014: val_loss improved from 0.22820 to 0.22527, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 634us/sample - loss: 0.1215 - mean_absolute_error: 0.3625 - val_loss: 0.2253 - val_mean_absolute_error: 0.5149
# Epoch 15/25
# 60928/61009 [============================>.] - ETA: 0s - loss: 0.1183 - mean_absolute_error: 0.3566
# Epoch 00015: val_loss did not improve from 0.22527
# 61009/61009 [==============================] - 38s 628us/sample - loss: 0.1183 - mean_absolute_error: 0.3566 - val_loss: 0.2270 - val_mean_absolute_error: 0.5169
# Epoch 16/25
# 60928/61009 [============================>.] - ETA: 0s - loss: 0.1162 - mean_absolute_error: 0.3528
# Epoch 00016: val_loss did not improve from 0.22527
# 61009/61009 [==============================] - 38s 627us/sample - loss: 0.1164 - mean_absolute_error: 0.3530 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 17/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00017: val_loss improved from 0.22527 to 0.22450, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 634us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2245 - val_mean_absolute_error: 0.5138
# Epoch 18/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1118 - mean_absolute_error: 0.3444
# Epoch 00018: val_loss improved from 0.22450 to 0.22402, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 633us/sample - loss: 0.1118 - mean_absolute_error: 0.3444 - val_loss: 0.2240 - val_mean_absolute_error: 0.5123
# Epoch 19/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00019: val_loss improved from 0.22402 to 0.22323, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2232 - val_mean_absolute_error: 0.5107
# Epoch 20/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1087 - mean_absolute_error: 0.3388
# Epoch 00020: val_loss did not improve from 0.22323
# 61009/61009 [==============================] - 38s 629us/sample - loss: 0.1087 - mean_absolute_error: 0.3388 - val_loss: 0.2240 - val_mean_absolute_error: 0.5110
# Epoch 21/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1077 - mean_absolute_error: 0.3370
# Epoch 00021: val_loss did not improve from 0.22323
# 61009/61009 [==============================] - 38s 630us/sample - loss: 0.1077 - mean_absolute_error: 0.3370 - val_loss: 0.2246 - val_mean_absolute_error: 0.5119
# Epoch 22/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1059 - mean_absolute_error: 0.3333
# Epoch 00022: val_loss did not improve from 0.22323
# 61009/61009 [==============================] - 38s 626us/sample - loss: 0.1059 - mean_absolute_error: 0.3334 - val_loss: 0.2241 - val_mean_absolute_error: 0.5117
# Epoch 23/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1053 - mean_absolute_error: 0.3322
# Epoch 00023: val_loss improved from 0.22323 to 0.22232, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 634us/sample - loss: 0.1053 - mean_absolute_error: 0.3322 - val_loss: 0.2223 - val_mean_absolute_error: 0.5083
# Epoch 24/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1038 - mean_absolute_error: 0.3296
# Epoch 00024: val_loss did not improve from 0.22232
# 61009/61009 [==============================] - 38s 629us/sample - loss: 0.1038 - mean_absolute_error: 0.3297 - val_loss: 0.2238 - val_mean_absolute_error: 0.5108
# Epoch 25/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1024 - mean_absolute_error: 0.3265
# Epoch 00025: val_loss did not improve from 0.22232
# 61009/61009 [==============================] - 38s 630us/sample - loss: 0.1024 - mean_absolute_error: 0.3265 - val_loss: 0.2232 - val_mean_absolute_error: 0.5100
