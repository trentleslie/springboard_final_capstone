# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = 152
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
FEATURE_COLUMNS = ["close_0","ema_0","high_0","low_0","open_0","rsi_0","sma_0","volume_0","close_1","ema_1","high_1","low_1","open_1","rsi_1","sma_1","volume_1",
                   "close_2","ema_2","high_2","low_2","open_2","rsi_2","sma_2","volume_2","close_3","ema_3","high_3","low_3","open_3","rsi_3","sma_3","volume_3",
                   "close_4","ema_4","high_4","low_4","open_4","rsi_4","sma_4","volume_4","close_5","ema_5","high_5","low_5","open_5","rsi_5","sma_5","volume_5",
                   "close_6","ema_6","high_6","low_6","open_6","rsi_6","sma_6","volume_6","close_7","ema_7","high_7","low_7","open_7","rsi_7","sma_7","volume_7",
                   "close_8","ema_8","high_8","low_8","open_8","rsi_8","sma_8","volume_8","close_9","ema_9","high_9","low_9","open_9","rsi_9","sma_9","volume_9",
                   "close_10","ema_10","high_10","low_10","open_10","rsi_10","sma_10","volume_10","close_11","ema_11","high_11","low_11","open_11","rsi_11","sma_11","volume_11",
                   "close_12","ema_12","high_12","low_12","open_12","rsi_12","sma_12","volume_12","close_13","ema_13","high_13","low_13","open_13","rsi_13","sma_13","volume_13",
                   "close_14","ema_14","high_14","low_14","open_14","rsi_14","sma_14","volume_14","close_15","ema_15","high_15","low_15","open_15","rsi_15","sma_15","volume_15",
                   "close_16","ema_16","high_16","low_16","open_16","rsi_16","sma_16","volume_16","close_17","ema_17","high_17","low_17","open_17","rsi_17","sma_17","volume_17",
                   "close_18","ema_18","high_18","low_18","open_18","rsi_18","sma_18","volume_18"]
TARGET_COLUMNS = ["close_19","high_19","low_19","open_19"]
# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "selu"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv('../data/processed/all_processed_20.csv')

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 67191 samples, validate on 28797 samples
# Epoch 1/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.4494 - mean_absolute_error: 0.8126
# Epoch 00001: val_loss improved from inf to 0.44916, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 54s 803us/sample - loss: 0.4493 - mean_absolute_error: 0.8125 - val_loss: 0.4492 - val_mean_absolute_error: 0.8097
# Epoch 2/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4338 - mean_absolute_error: 0.7931
# Epoch 00002: val_loss improved from 0.44916 to 0.43941, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 46s 678us/sample - loss: 0.4338 - mean_absolute_error: 0.7930 - val_loss: 0.4394 - val_mean_absolute_error: 0.7986
# Epoch 3/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4204 - mean_absolute_error: 0.7767
# Epoch 00003: val_loss improved from 0.43941 to 0.43053, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 653us/sample - loss: 0.4203 - mean_absolute_error: 0.7766 - val_loss: 0.4305 - val_mean_absolute_error: 0.7874
# Epoch 4/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4008 - mean_absolute_error: 0.7524
# Epoch 00004: val_loss improved from 0.43053 to 0.41972, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 668us/sample - loss: 0.4008 - mean_absolute_error: 0.7524 - val_loss: 0.4197 - val_mean_absolute_error: 0.7742
# Epoch 5/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3765 - mean_absolute_error: 0.7224
# Epoch 00005: val_loss improved from 0.41972 to 0.40628, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 657us/sample - loss: 0.3766 - mean_absolute_error: 0.7225 - val_loss: 0.4063 - val_mean_absolute_error: 0.7572
# Epoch 6/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3486 - mean_absolute_error: 0.6871
# Epoch 00006: val_loss improved from 0.40628 to 0.39945, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 663us/sample - loss: 0.3487 - mean_absolute_error: 0.6871 - val_loss: 0.3994 - val_mean_absolute_error: 0.7486
# Epoch 7/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.3208 - mean_absolute_error: 0.6520
# Epoch 00007: val_loss improved from 0.39945 to 0.38856, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 663us/sample - loss: 0.3209 - mean_absolute_error: 0.6521 - val_loss: 0.3886 - val_mean_absolute_error: 0.7350
# Epoch 8/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2972 - mean_absolute_error: 0.6219
# Epoch 00008: val_loss improved from 0.38856 to 0.38411, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 666us/sample - loss: 0.2973 - mean_absolute_error: 0.6219 - val_loss: 0.3841 - val_mean_absolute_error: 0.7290
# Epoch 9/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2762 - mean_absolute_error: 0.5945
# Epoch 00009: val_loss improved from 0.38411 to 0.38358, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 661us/sample - loss: 0.2761 - mean_absolute_error: 0.5944 - val_loss: 0.3836 - val_mean_absolute_error: 0.7286
# Epoch 10/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2597 - mean_absolute_error: 0.5729
# Epoch 00010: val_loss improved from 0.38358 to 0.37665, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 662us/sample - loss: 0.2598 - mean_absolute_error: 0.5730 - val_loss: 0.3767 - val_mean_absolute_error: 0.7188
# Epoch 11/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2476 - mean_absolute_error: 0.5571
# Epoch 00011: val_loss did not improve from 0.37665
# 67191/67191 [==============================] - 45s 670us/sample - loss: 0.2476 - mean_absolute_error: 0.5571 - val_loss: 0.3795 - val_mean_absolute_error: 0.7228
# Epoch 12/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2382 - mean_absolute_error: 0.5440
# Epoch 00012: val_loss improved from 0.37665 to 0.37486, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 662us/sample - loss: 0.2382 - mean_absolute_error: 0.5440 - val_loss: 0.3749 - val_mean_absolute_error: 0.7170
# Epoch 13/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2310 - mean_absolute_error: 0.5347
# Epoch 00013: val_loss did not improve from 0.37486
# 67191/67191 [==============================] - 44s 659us/sample - loss: 0.2310 - mean_absolute_error: 0.5346 - val_loss: 0.3751 - val_mean_absolute_error: 0.7172
# Epoch 14/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2243 - mean_absolute_error: 0.5249
# Epoch 00014: val_loss improved from 0.37486 to 0.37092, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 671us/sample - loss: 0.2244 - mean_absolute_error: 0.5250 - val_loss: 0.3709 - val_mean_absolute_error: 0.7114
# Epoch 15/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2199 - mean_absolute_error: 0.5187
# Epoch 00015: val_loss did not improve from 0.37092
# 67191/67191 [==============================] - 44s 661us/sample - loss: 0.2199 - mean_absolute_error: 0.5187 - val_loss: 0.3715 - val_mean_absolute_error: 0.7123
# Epoch 16/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2167 - mean_absolute_error: 0.5142
# Epoch 00016: val_loss improved from 0.37092 to 0.37048, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 47s 700us/sample - loss: 0.2167 - mean_absolute_error: 0.5142 - val_loss: 0.3705 - val_mean_absolute_error: 0.7102
# Epoch 17/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2138 - mean_absolute_error: 0.5100
# Epoch 00017: val_loss improved from 0.37048 to 0.36916, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 48s 710us/sample - loss: 0.2138 - mean_absolute_error: 0.5100 - val_loss: 0.3692 - val_mean_absolute_error: 0.7086
# Epoch 18/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2114 - mean_absolute_error: 0.5063
# Epoch 00018: val_loss improved from 0.36916 to 0.36893, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 662us/sample - loss: 0.2115 - mean_absolute_error: 0.5063 - val_loss: 0.3689 - val_mean_absolute_error: 0.7088
# Epoch 19/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2097 - mean_absolute_error: 0.5040
# Epoch 00019: val_loss improved from 0.36893 to 0.36587, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 46s 679us/sample - loss: 0.2097 - mean_absolute_error: 0.5040 - val_loss: 0.3659 - val_mean_absolute_error: 0.7045
# Epoch 20/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2075 - mean_absolute_error: 0.5004
# Epoch 00020: val_loss did not improve from 0.36587
# 67191/67191 [==============================] - 47s 699us/sample - loss: 0.2075 - mean_absolute_error: 0.5005 - val_loss: 0.3665 - val_mean_absolute_error: 0.7053
# Epoch 21/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2065 - mean_absolute_error: 0.4995
# Epoch 00021: val_loss did not improve from 0.36587
# 67191/67191 [==============================] - 45s 673us/sample - loss: 0.2066 - mean_absolute_error: 0.4996 - val_loss: 0.3666 - val_mean_absolute_error: 0.7055
# Epoch 22/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2046 - mean_absolute_error: 0.4963
# Epoch 00022: val_loss improved from 0.36587 to 0.36558, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 669us/sample - loss: 0.2046 - mean_absolute_error: 0.4963 - val_loss: 0.3656 - val_mean_absolute_error: 0.7044
# Epoch 23/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2032 - mean_absolute_error: 0.4945
# Epoch 00023: val_loss did not improve from 0.36558
# 67191/67191 [==============================] - 43s 645us/sample - loss: 0.2032 - mean_absolute_error: 0.4945 - val_loss: 0.3659 - val_mean_absolute_error: 0.7042
# Epoch 24/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2021 - mean_absolute_error: 0.4924
# Epoch 00024: val_loss improved from 0.36558 to 0.36397, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 665us/sample - loss: 0.2021 - mean_absolute_error: 0.4925 - val_loss: 0.3640 - val_mean_absolute_error: 0.7020
# Epoch 25/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2018 - mean_absolute_error: 0.4918
# Epoch 00025: val_loss improved from 0.36397 to 0.36362, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 667us/sample - loss: 0.2018 - mean_absolute_error: 0.4918 - val_loss: 0.3636 - val_mean_absolute_error: 0.7013
# Epoch 26/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1999 - mean_absolute_error: 0.4891
# Epoch 00026: val_loss improved from 0.36362 to 0.36249, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 658us/sample - loss: 0.2000 - mean_absolute_error: 0.4892 - val_loss: 0.3625 - val_mean_absolute_error: 0.7002
# Epoch 27/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1995 - mean_absolute_error: 0.4885
# Epoch 00027: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 46s 680us/sample - loss: 0.1995 - mean_absolute_error: 0.4884 - val_loss: 0.3633 - val_mean_absolute_error: 0.7009
# Epoch 28/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1985 - mean_absolute_error: 0.4871
# Epoch 00028: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 48s 710us/sample - loss: 0.1985 - mean_absolute_error: 0.4870 - val_loss: 0.3636 - val_mean_absolute_error: 0.7011
# Epoch 29/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1982 - mean_absolute_error: 0.4864
# Epoch 00029: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 46s 692us/sample - loss: 0.1983 - mean_absolute_error: 0.4865 - val_loss: 0.3641 - val_mean_absolute_error: 0.7017
# Epoch 30/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1976 - mean_absolute_error: 0.4856
# Epoch 00030: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 44s 658us/sample - loss: 0.1976 - mean_absolute_error: 0.4857 - val_loss: 0.3626 - val_mean_absolute_error: 0.6997
# Epoch 31/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1966 - mean_absolute_error: 0.4839
# Epoch 00031: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 44s 659us/sample - loss: 0.1966 - mean_absolute_error: 0.4839 - val_loss: 0.3628 - val_mean_absolute_error: 0.6999
# Epoch 32/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1959 - mean_absolute_error: 0.4828
# Epoch 00032: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 44s 655us/sample - loss: 0.1959 - mean_absolute_error: 0.4828 - val_loss: 0.3630 - val_mean_absolute_error: 0.6999
# Epoch 33/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1959 - mean_absolute_error: 0.4828
# Epoch 00033: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 44s 660us/sample - loss: 0.1959 - mean_absolute_error: 0.4828 - val_loss: 0.3626 - val_mean_absolute_error: 0.6999
# Epoch 34/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1955 - mean_absolute_error: 0.4825
# Epoch 00034: val_loss did not improve from 0.36249
# 67191/67191 [==============================] - 45s 674us/sample - loss: 0.1956 - mean_absolute_error: 0.4826 - val_loss: 0.3628 - val_mean_absolute_error: 0.6999
# Epoch 35/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1947 - mean_absolute_error: 0.4810
# Epoch 00035: val_loss improved from 0.36249 to 0.36220, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 653us/sample - loss: 0.1946 - mean_absolute_error: 0.4809 - val_loss: 0.3622 - val_mean_absolute_error: 0.6990
# Epoch 36/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1942 - mean_absolute_error: 0.4800
# Epoch 00036: val_loss did not improve from 0.36220
# 67191/67191 [==============================] - 46s 677us/sample - loss: 0.1942 - mean_absolute_error: 0.4799 - val_loss: 0.3639 - val_mean_absolute_error: 0.7014
# Epoch 37/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1936 - mean_absolute_error: 0.4790
# Epoch 00037: val_loss did not improve from 0.36220
# 67191/67191 [==============================] - 45s 667us/sample - loss: 0.1936 - mean_absolute_error: 0.4790 - val_loss: 0.3635 - val_mean_absolute_error: 0.7004
# Epoch 38/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1935 - mean_absolute_error: 0.4789
# Epoch 00038: val_loss improved from 0.36220 to 0.36203, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 657us/sample - loss: 0.1935 - mean_absolute_error: 0.4789 - val_loss: 0.3620 - val_mean_absolute_error: 0.6989
# Epoch 39/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1940 - mean_absolute_error: 0.4796
# Epoch 00039: val_loss improved from 0.36203 to 0.36172, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 45s 668us/sample - loss: 0.1940 - mean_absolute_error: 0.4795 - val_loss: 0.3617 - val_mean_absolute_error: 0.6986
# Epoch 40/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1929 - mean_absolute_error: 0.4780
# Epoch 00040: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 45s 663us/sample - loss: 0.1929 - mean_absolute_error: 0.4780 - val_loss: 0.3632 - val_mean_absolute_error: 0.7005
# Epoch 41/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1921 - mean_absolute_error: 0.4766
# Epoch 00041: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 45s 670us/sample - loss: 0.1921 - mean_absolute_error: 0.4766 - val_loss: 0.3618 - val_mean_absolute_error: 0.6981
# Epoch 42/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1921 - mean_absolute_error: 0.4768
# Epoch 00042: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 45s 676us/sample - loss: 0.1921 - mean_absolute_error: 0.4768 - val_loss: 0.3631 - val_mean_absolute_error: 0.6996
# Epoch 43/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1924 - mean_absolute_error: 0.4773
# Epoch 00043: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 48s 708us/sample - loss: 0.1924 - mean_absolute_error: 0.4773 - val_loss: 0.3637 - val_mean_absolute_error: 0.7006
# Epoch 44/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1921 - mean_absolute_error: 0.4766
# Epoch 00044: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 46s 687us/sample - loss: 0.1920 - mean_absolute_error: 0.4766 - val_loss: 0.3638 - val_mean_absolute_error: 0.7005
# Epoch 45/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1915 - mean_absolute_error: 0.4759
# Epoch 00045: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 44s 658us/sample - loss: 0.1915 - mean_absolute_error: 0.4759 - val_loss: 0.3632 - val_mean_absolute_error: 0.6997
# Epoch 46/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1909 - mean_absolute_error: 0.4748
# Epoch 00046: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 44s 655us/sample - loss: 0.1909 - mean_absolute_error: 0.4748 - val_loss: 0.3630 - val_mean_absolute_error: 0.6996
# Epoch 47/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.1904 - mean_absolute_error: 0.4742
# Epoch 00047: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 44s 660us/sample - loss: 0.1908 - mean_absolute_error: 0.4746 - val_loss: 0.3639 - val_mean_absolute_error: 0.7007
# Epoch 48/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1910 - mean_absolute_error: 0.4751
# Epoch 00048: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 45s 665us/sample - loss: 0.1909 - mean_absolute_error: 0.4750 - val_loss: 0.3619 - val_mean_absolute_error: 0.6980
# Epoch 49/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1904 - mean_absolute_error: 0.4739
# Epoch 00049: val_loss did not improve from 0.36172
# 67191/67191 [==============================] - 44s 660us/sample - loss: 0.1904 - mean_absolute_error: 0.4738 - val_loss: 0.3634 - val_mean_absolute_error: 0.6998
# Epoch 50/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.1901 - mean_absolute_error: 0.4735
# Epoch 00050: val_loss improved from 0.36172 to 0.36126, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-selu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 44s 657us/sample - loss: 0.1901 - mean_absolute_error: 0.4736 - val_loss: 0.3613 - val_mean_absolute_error: 0.6977
