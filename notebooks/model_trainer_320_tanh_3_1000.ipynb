# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(4, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 320

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 25

LAYER_ACTIVATION = "tanh"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

with tf.device('/device:GPU:0'):
    history = model.fit(X_train, y_train,
                        batch_size=BATCH_SIZE,
                        epochs=EPOCHS,
                        validation_data=(X_test, y_test),
                        callbacks=[checkpointer, tensorboard],
                        verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 61009 samples, validate on 26148 samples
# Epoch 1/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00001: val_loss improved from inf to 0.32372, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 49s 806us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.3237 - val_mean_absolute_error: 0.6502
# Epoch 2/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.2974 - mean_absolute_error: 0.6144
# Epoch 00002: val_loss improved from 0.32372 to 0.29482, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 40s 650us/sample - loss: 0.2974 - mean_absolute_error: 0.6144 - val_loss: 0.2948 - val_mean_absolute_error: 0.6116
# Epoch 3/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00003: val_loss improved from 0.29482 to 0.28034, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 630us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2803 - val_mean_absolute_error: 0.5914
# Epoch 4/25
# 60928/61009 [============================>.] - ETA: 0s - loss: 0.2321 - mean_absolute_error: 0.5226
# Epoch 00004: val_loss improved from 0.28034 to 0.27136, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 634us/sample - loss: 0.2320 - mean_absolute_error: 0.5225 - val_loss: 0.2714 - val_mean_absolute_error: 0.5787
# Epoch 5/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.2125 - mean_absolute_error: 0.4936
# Epoch 00005: val_loss improved from 0.27136 to 0.26692, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 634us/sample - loss: 0.2125 - mean_absolute_error: 0.4936 - val_loss: 0.2669 - val_mean_absolute_error: 0.5712
# Epoch 6/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00006: val_loss did not improve from 0.26692
# 61009/61009 [==============================] - 38s 626us/sample - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 7/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1945 - mean_absolute_error: 0.4648
# Epoch 00007: val_loss improved from 0.26692 to 0.26053, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 630us/sample - loss: 0.1945 - mean_absolute_error: 0.4648 - val_loss: 0.2605 - val_mean_absolute_error: 0.5623
# Epoch 8/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1873 - mean_absolute_error: 0.4525
# Epoch 00008: val_loss improved from 0.26053 to 0.25614, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: 0.1873 - mean_absolute_error: 0.4525 - val_loss: 0.2561 - val_mean_absolute_error: 0.5550
# Epoch 9/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1821 - mean_absolute_error: 0.4439
# Epoch 00009: val_loss did not improve from 0.25614
# 61009/61009 [==============================] - 38s 623us/sample - loss: 0.1821 - mean_absolute_error: 0.4439 - val_loss: 0.2589 - val_mean_absolute_error: 0.5589
# Epoch 10/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1787 - mean_absolute_error: 0.4379
# Epoch 00010: val_loss improved from 0.25614 to 0.25408, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 631us/sample - loss: 0.1787 - mean_absolute_error: 0.4379 - val_loss: 0.2541 - val_mean_absolute_error: 0.5521
# Epoch 11/25
# 60928/61009 [============================>.] - ETA: 0s - loss: 0.1759 - mean_absolute_error: 0.4330
# Epoch 00011: val_loss improved from 0.25408 to 0.25318, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 629us/sample - loss: 0.1759 - mean_absolute_error: 0.4330 - val_loss: 0.2532 - val_mean_absolute_error: 0.5498
# Epoch 12/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1734 - mean_absolute_error: 0.4283
# Epoch 00012: val_loss improved from 0.25318 to 0.25288, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 625us/sample - loss: 0.1734 - mean_absolute_error: 0.4283 - val_loss: 0.2529 - val_mean_absolute_error: 0.5491
# Epoch 13/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1720 - mean_absolute_error: 0.4255
# Epoch 00013: val_loss did not improve from 0.25288
# 61009/61009 [==============================] - 38s 623us/sample - loss: 0.1720 - mean_absolute_error: 0.4255 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 14/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00014: val_loss did not improve from 0.25288
# 61009/61009 [==============================] - 38s 622us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2543 - val_mean_absolute_error: 0.5510
# Epoch 15/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00015: val_loss improved from 0.25288 to 0.25186, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 627us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2519 - val_mean_absolute_error: 0.5473
# Epoch 16/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1646 - mean_absolute_error: 0.4119
# Epoch 00016: val_loss improved from 0.25186 to 0.25042, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: 0.1646 - mean_absolute_error: 0.4119 - val_loss: 0.2504 - val_mean_absolute_error: 0.5455
# Epoch 17/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1639 - mean_absolute_error: 0.4104
# Epoch 00017: val_loss did not improve from 0.25042
# 61009/61009 [==============================] - 38s 621us/sample - loss: 0.1640 - mean_absolute_error: 0.4105 - val_loss: 0.2528 - val_mean_absolute_error: 0.5485
# Epoch 18/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00018: val_loss improved from 0.25042 to 0.24929, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 629us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2493 - val_mean_absolute_error: 0.5431
# Epoch 19/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1605 - mean_absolute_error: 0.4040
# Epoch 00019: val_loss did not improve from 0.24929
# 61009/61009 [==============================] - 38s 622us/sample - loss: 0.1605 - mean_absolute_error: 0.4040 - val_loss: 0.2495 - val_mean_absolute_error: 0.5430
# Epoch 20/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1593 - mean_absolute_error: 0.4016
# Epoch 00020: val_loss did not improve from 0.24929
# 61009/61009 [==============================] - 38s 620us/sample - loss: 0.1593 - mean_absolute_error: 0.4016 - val_loss: 0.2512 - val_mean_absolute_error: 0.5456
# Epoch 21/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00021: val_loss did not improve from 0.24929
# 61009/61009 [==============================] - 38s 623us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2494 - val_mean_absolute_error: 0.5426
# Epoch 22/25
# 60928/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00022: val_loss improved from 0.24929 to 0.24733, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 628us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2473 - val_mean_absolute_error: 0.5401
# Epoch 23/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1552 - mean_absolute_error: 0.3935
# Epoch 00023: val_loss did not improve from 0.24733
# 61009/61009 [==============================] - 38s 622us/sample - loss: 0.1552 - mean_absolute_error: 0.3935 - val_loss: 0.2475 - val_mean_absolute_error: 0.5391
# Epoch 24/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1552 - mean_absolute_error: 0.3930
# Epoch 00024: val_loss improved from 0.24733 to 0.24694, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 632us/sample - loss: 0.1552 - mean_absolute_error: 0.3930 - val_loss: 0.2469 - val_mean_absolute_error: 0.5387
# Epoch 25/25
# 60992/61009 [============================>.] - ETA: 0s - loss: 0.1540 - mean_absolute_error: 0.3907
# Epoch 00025: val_loss did not improve from 0.24694
# 61009/61009 [==============================] - 38s 622us/sample - loss: 0.1540 - mean_absolute_error: 0.3907 - val_loss: 0.2470 - val_mean_absolute_error: 0.5391
