# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 80

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "linear"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 65427 samples, validate on 28041 samples
# Epoch 1/50
# 65408/65427 [============================>.] - ETA: 0s - loss: 0.3995 - mean_absolute_error: 0.7502
# Epoch 00001: val_loss improved from inf to 0.36732, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 44s 671us/sample - loss: 0.3995 - mean_absolute_error: 0.7502 - val_loss: 0.3673 - val_mean_absolute_error: 0.7119
# Epoch 2/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.3516 - mean_absolute_error: 0.6908
# Epoch 00002: val_loss improved from 0.36732 to 0.33784, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 36s 557us/sample - loss: 0.3517 - mean_absolute_error: 0.6909 - val_loss: 0.3378 - val_mean_absolute_error: 0.6748
# Epoch 3/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.3077 - mean_absolute_error: 0.6356
# Epoch 00003: val_loss improved from 0.33784 to 0.32018, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 36s 557us/sample - loss: 0.3078 - mean_absolute_error: 0.6356 - val_loss: 0.3202 - val_mean_absolute_error: 0.6529
# Epoch 4/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.2713 - mean_absolute_error: 0.5884
# Epoch 00004: val_loss improved from 0.32018 to 0.30916, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 561us/sample - loss: 0.2713 - mean_absolute_error: 0.5884 - val_loss: 0.3092 - val_mean_absolute_error: 0.6378
# Epoch 5/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.2472 - mean_absolute_error: 0.5563
# Epoch 00005: val_loss improved from 0.30916 to 0.30265, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 559us/sample - loss: 0.2472 - mean_absolute_error: 0.5563 - val_loss: 0.3027 - val_mean_absolute_error: 0.6294
# Epoch 6/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.2286 - mean_absolute_error: 0.5309
# Epoch 00006: val_loss improved from 0.30265 to 0.29877, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 36s 557us/sample - loss: 0.2285 - mean_absolute_error: 0.5308 - val_loss: 0.2988 - val_mean_absolute_error: 0.6242
# Epoch 7/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.2160 - mean_absolute_error: 0.5136
# Epoch 00007: val_loss improved from 0.29877 to 0.29377, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 560us/sample - loss: 0.2159 - mean_absolute_error: 0.5136 - val_loss: 0.2938 - val_mean_absolute_error: 0.6172
# Epoch 8/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.2064 - mean_absolute_error: 0.5005
# Epoch 00008: val_loss improved from 0.29377 to 0.29321, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 568us/sample - loss: 0.2064 - mean_absolute_error: 0.5005 - val_loss: 0.2932 - val_mean_absolute_error: 0.6161
# Epoch 9/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1981 - mean_absolute_error: 0.4881
# Epoch 00009: val_loss improved from 0.29321 to 0.29096, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 569us/sample - loss: 0.1982 - mean_absolute_error: 0.4882 - val_loss: 0.2910 - val_mean_absolute_error: 0.6132
# Epoch 10/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1921 - mean_absolute_error: 0.4799
# Epoch 00010: val_loss improved from 0.29096 to 0.28917, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 566us/sample - loss: 0.1921 - mean_absolute_error: 0.4799 - val_loss: 0.2892 - val_mean_absolute_error: 0.6114
# Epoch 11/50
# 65408/65427 [============================>.] - ETA: 0s - loss: 0.1876 - mean_absolute_error: 0.4729
# Epoch 00011: val_loss did not improve from 0.28917
# 65427/65427 [==============================] - 38s 577us/sample - loss: 0.1876 - mean_absolute_error: 0.4729 - val_loss: 0.2916 - val_mean_absolute_error: 0.6138
# Epoch 12/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1873 - mean_absolute_error: 0.4725
# Epoch 00012: val_loss improved from 0.28917 to 0.28777, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 569us/sample - loss: 0.1873 - mean_absolute_error: 0.4725 - val_loss: 0.2878 - val_mean_absolute_error: 0.6079
# Epoch 13/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1834 - mean_absolute_error: 0.4669
# Epoch 00013: val_loss did not improve from 0.28777
# 65427/65427 [==============================] - 37s 562us/sample - loss: 0.1834 - mean_absolute_error: 0.4669 - val_loss: 0.2897 - val_mean_absolute_error: 0.6104
# Epoch 14/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1778 - mean_absolute_error: 0.4590
# Epoch 00014: val_loss did not improve from 0.28777
# 65427/65427 [==============================] - 37s 567us/sample - loss: 0.1778 - mean_absolute_error: 0.4590 - val_loss: 0.2883 - val_mean_absolute_error: 0.6084
# Epoch 15/50
# 65408/65427 [============================>.] - ETA: 0s - loss: 0.1782 - mean_absolute_error: 0.4592
# Epoch 00015: val_loss did not improve from 0.28777
# 65427/65427 [==============================] - 37s 568us/sample - loss: 0.1783 - mean_absolute_error: 0.4592 - val_loss: 0.2882 - val_mean_absolute_error: 0.6090
# Epoch 16/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1739 - mean_absolute_error: 0.4526
# Epoch 00016: val_loss improved from 0.28777 to 0.28742, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 37s 563us/sample - loss: 0.1739 - mean_absolute_error: 0.4526 - val_loss: 0.2874 - val_mean_absolute_error: 0.6070
# Epoch 17/50
# 65408/65427 [============================>.] - ETA: 0s - loss: 0.1722 - mean_absolute_error: 0.4495
# Epoch 00017: val_loss did not improve from 0.28742
# 65427/65427 [==============================] - 37s 558us/sample - loss: 0.1722 - mean_absolute_error: 0.4495 - val_loss: 0.2922 - val_mean_absolute_error: 0.6122
# Epoch 18/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1732 - mean_absolute_error: 0.4512
# Epoch 00018: val_loss did not improve from 0.28742
# 65427/65427 [==============================] - 35s 541us/sample - loss: 0.1733 - mean_absolute_error: 0.4512 - val_loss: 0.2887 - val_mean_absolute_error: 0.6089
# Epoch 19/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1707 - mean_absolute_error: 0.4483
# Epoch 00019: val_loss did not improve from 0.28742
# 65427/65427 [==============================] - 35s 538us/sample - loss: 0.1707 - mean_absolute_error: 0.4482 - val_loss: 0.2912 - val_mean_absolute_error: 0.6108
# Epoch 20/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1670 - mean_absolute_error: 0.4423
# Epoch 00020: val_loss improved from 0.28742 to 0.28703, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 36s 551us/sample - loss: 0.1670 - mean_absolute_error: 0.4423 - val_loss: 0.2870 - val_mean_absolute_error: 0.6053
# Epoch 21/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1667 - mean_absolute_error: 0.4415
# Epoch 00021: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 35s 541us/sample - loss: 0.1666 - mean_absolute_error: 0.4414 - val_loss: 0.2891 - val_mean_absolute_error: 0.6074
# Epoch 22/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1658 - mean_absolute_error: 0.4406
# Epoch 00022: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 35s 541us/sample - loss: 0.1658 - mean_absolute_error: 0.4405 - val_loss: 0.2876 - val_mean_absolute_error: 0.6066
# Epoch 23/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1652 - mean_absolute_error: 0.4397
# Epoch 00023: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 35s 540us/sample - loss: 0.1653 - mean_absolute_error: 0.4397 - val_loss: 0.2879 - val_mean_absolute_error: 0.6068
# Epoch 24/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1640 - mean_absolute_error: 0.4380
# Epoch 00024: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 35s 542us/sample - loss: 0.1641 - mean_absolute_error: 0.4381 - val_loss: 0.2909 - val_mean_absolute_error: 0.6091
# Epoch 25/50
# 65408/65427 [============================>.] - ETA: 0s - loss: 0.1639 - mean_absolute_error: 0.4372
# Epoch 00025: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 39s 592us/sample - loss: 0.1639 - mean_absolute_error: 0.4373 - val_loss: 0.2896 - val_mean_absolute_error: 0.6080
# Epoch 26/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1617 - mean_absolute_error: 0.4337
# Epoch 00026: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 35s 540us/sample - loss: 0.1617 - mean_absolute_error: 0.4336 - val_loss: 0.2908 - val_mean_absolute_error: 0.6089
# Epoch 27/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1622 - mean_absolute_error: 0.4344
# Epoch 00027: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 36s 548us/sample - loss: 0.1622 - mean_absolute_error: 0.4344 - val_loss: 0.2888 - val_mean_absolute_error: 0.6076
# Epoch 28/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1613 - mean_absolute_error: 0.4331
# Epoch 00028: val_loss did not improve from 0.28703
# 65427/65427 [==============================] - 35s 540us/sample - loss: 0.1613 - mean_absolute_error: 0.4330 - val_loss: 0.2898 - val_mean_absolute_error: 0.6074
# Epoch 29/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1601 - mean_absolute_error: 0.4313
# Epoch 00029: val_loss improved from 0.28703 to 0.28674, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 36s 544us/sample - loss: 0.1601 - mean_absolute_error: 0.4313 - val_loss: 0.2867 - val_mean_absolute_error: 0.6050
# Epoch 30/50
# 65408/65427 [============================>.] - ETA: 0s - loss: 0.1605 - mean_absolute_error: 0.4315
# Epoch 00030: val_loss did not improve from 0.28674
# 65427/65427 [==============================] - 36s 546us/sample - loss: 0.1605 - mean_absolute_error: 0.4315 - val_loss: 0.2911 - val_mean_absolute_error: 0.6098
# Epoch 31/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1595 - mean_absolute_error: 0.4302
# Epoch 00031: val_loss did not improve from 0.28674
# 65427/65427 [==============================] - 35s 541us/sample - loss: 0.1595 - mean_absolute_error: 0.4302 - val_loss: 0.2907 - val_mean_absolute_error: 0.6094
# Epoch 32/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1582 - mean_absolute_error: 0.4288
# Epoch 00032: val_loss did not improve from 0.28674
# 65427/65427 [==============================] - 35s 540us/sample - loss: 0.1582 - mean_absolute_error: 0.4289 - val_loss: 0.2896 - val_mean_absolute_error: 0.6077
# Epoch 33/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1589 - mean_absolute_error: 0.4290
# Epoch 00033: val_loss improved from 0.28674 to 0.28638, saving model to results\2021-12-02_MIXED-80-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 65427/65427 [==============================] - 36s 545us/sample - loss: 0.1589 - mean_absolute_error: 0.4290 - val_loss: 0.2864 - val_mean_absolute_error: 0.6043
# Epoch 34/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1576 - mean_absolute_error: 0.4269
# Epoch 00034: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 550us/sample - loss: 0.1576 - mean_absolute_error: 0.4269 - val_loss: 0.2877 - val_mean_absolute_error: 0.6059
# Epoch 35/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1582 - mean_absolute_error: 0.4279
# Epoch 00035: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 552us/sample - loss: 0.1582 - mean_absolute_error: 0.4279 - val_loss: 0.2912 - val_mean_absolute_error: 0.6095
# Epoch 36/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1582 - mean_absolute_error: 0.4282
# Epoch 00036: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 553us/sample - loss: 0.1582 - mean_absolute_error: 0.4282 - val_loss: 0.2880 - val_mean_absolute_error: 0.6059
# Epoch 37/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1568 - mean_absolute_error: 0.4258
# Epoch 00037: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 558us/sample - loss: 0.1568 - mean_absolute_error: 0.4258 - val_loss: 0.2884 - val_mean_absolute_error: 0.6059
# Epoch 38/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1565 - mean_absolute_error: 0.4254
# Epoch 00038: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 553us/sample - loss: 0.1565 - mean_absolute_error: 0.4254 - val_loss: 0.2889 - val_mean_absolute_error: 0.6067
# Epoch 39/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1544 - mean_absolute_error: 0.4223
# Epoch 00039: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 552us/sample - loss: 0.1544 - mean_absolute_error: 0.4223 - val_loss: 0.2912 - val_mean_absolute_error: 0.6091
# Epoch 40/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1557 - mean_absolute_error: 0.4243
# Epoch 00040: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 552us/sample - loss: 0.1556 - mean_absolute_error: 0.4243 - val_loss: 0.2874 - val_mean_absolute_error: 0.6049
# Epoch 41/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1552 - mean_absolute_error: 0.4237
# Epoch 00041: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 552us/sample - loss: 0.1552 - mean_absolute_error: 0.4237 - val_loss: 0.2903 - val_mean_absolute_error: 0.6088
# Epoch 42/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1554 - mean_absolute_error: 0.4237
# Epoch 00042: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 543us/sample - loss: 0.1554 - mean_absolute_error: 0.4237 - val_loss: 0.2889 - val_mean_absolute_error: 0.6070
# Epoch 43/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1547 - mean_absolute_error: 0.4226
# Epoch 00043: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 546us/sample - loss: 0.1547 - mean_absolute_error: 0.4226 - val_loss: 0.2905 - val_mean_absolute_error: 0.6086
# Epoch 44/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1530 - mean_absolute_error: 0.4206
# Epoch 00044: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 543us/sample - loss: 0.1530 - mean_absolute_error: 0.4206 - val_loss: 0.2890 - val_mean_absolute_error: 0.6067
# Epoch 45/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1543 - mean_absolute_error: 0.4215
# Epoch 00045: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 544us/sample - loss: 0.1543 - mean_absolute_error: 0.4215 - val_loss: 0.2915 - val_mean_absolute_error: 0.6100
# Epoch 46/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1543 - mean_absolute_error: 0.4220
# Epoch 00046: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 543us/sample - loss: 0.1543 - mean_absolute_error: 0.4220 - val_loss: 0.2901 - val_mean_absolute_error: 0.6081
# Epoch 47/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1534 - mean_absolute_error: 0.4208
# Epoch 00047: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 543us/sample - loss: 0.1534 - mean_absolute_error: 0.4208 - val_loss: 0.2891 - val_mean_absolute_error: 0.6072
# Epoch 48/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1530 - mean_absolute_error: 0.4200
# Epoch 00048: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 35s 542us/sample - loss: 0.1530 - mean_absolute_error: 0.4200 - val_loss: 0.2885 - val_mean_absolute_error: 0.6065
# Epoch 49/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1530 - mean_absolute_error: 0.4200
# Epoch 00049: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 544us/sample - loss: 0.1530 - mean_absolute_error: 0.4200 - val_loss: 0.2880 - val_mean_absolute_error: 0.6056
# Epoch 50/50
# 65344/65427 [============================>.] - ETA: 0s - loss: 0.1530 - mean_absolute_error: 0.4198
# Epoch 00050: val_loss did not improve from 0.28638
# 65427/65427 [==============================] - 36s 543us/sample - loss: 0.1530 - mean_absolute_error: 0.4199 - val_loss: 0.2878 - val_mean_absolute_error: 0.6051
