# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 640

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 20

LAYER_ACTIVATION = "linear"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 48963 samples, validate on 20985 samples
# Epoch 1/20
#    64/48963 [..............................] - ETA: 1:32:36 - loss: 0.4181 - mean_absolute_error: 0.7690WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.108999). Check your callbacks.
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.3576 - mean_absolute_error: 0.6876
# Epoch 00001: val_loss improved from inf to 0.32008, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 48s 977us/sample - loss: 0.3576 - mean_absolute_error: 0.6876 - val_loss: 0.3201 - val_mean_absolute_error: 0.6414
# Epoch 2/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.2821 - mean_absolute_error: 0.5923
# Epoch 00002: val_loss improved from 0.32008 to 0.29786, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 40s 808us/sample - loss: 0.2820 - mean_absolute_error: 0.5923 - val_loss: 0.2979 - val_mean_absolute_error: 0.6117
# Epoch 3/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.2399 - mean_absolute_error: 0.5364
# Epoch 00003: val_loss improved from 0.29786 to 0.28324, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 797us/sample - loss: 0.2399 - mean_absolute_error: 0.5364 - val_loss: 0.2832 - val_mean_absolute_error: 0.5939
# Epoch 4/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.2140 - mean_absolute_error: 0.5008
# Epoch 00004: val_loss improved from 0.28324 to 0.27552, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 791us/sample - loss: 0.2140 - mean_absolute_error: 0.5008 - val_loss: 0.2755 - val_mean_absolute_error: 0.5826
# Epoch 5/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1985 - mean_absolute_error: 0.4790
# Epoch 00005: val_loss improved from 0.27552 to 0.27418, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 791us/sample - loss: 0.1985 - mean_absolute_error: 0.4790 - val_loss: 0.2742 - val_mean_absolute_error: 0.5819
# Epoch 6/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.1886 - mean_absolute_error: 0.4649
# Epoch 00006: val_loss improved from 0.27418 to 0.27147, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 796us/sample - loss: 0.1886 - mean_absolute_error: 0.4650 - val_loss: 0.2715 - val_mean_absolute_error: 0.5773
# Epoch 7/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1815 - mean_absolute_error: 0.4546
# Epoch 00007: val_loss improved from 0.27147 to 0.27019, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 793us/sample - loss: 0.1815 - mean_absolute_error: 0.4546 - val_loss: 0.2702 - val_mean_absolute_error: 0.5761
# Epoch 8/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1757 - mean_absolute_error: 0.4463
# Epoch 00008: val_loss improved from 0.27019 to 0.26895, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 788us/sample - loss: 0.1756 - mean_absolute_error: 0.4463 - val_loss: 0.2689 - val_mean_absolute_error: 0.5725
# Epoch 9/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1740 - mean_absolute_error: 0.4431
# Epoch 00009: val_loss did not improve from 0.26895
# 48963/48963 [==============================] - 38s 779us/sample - loss: 0.1740 - mean_absolute_error: 0.4432 - val_loss: 0.2706 - val_mean_absolute_error: 0.5756
# Epoch 10/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.1715 - mean_absolute_error: 0.4392
# Epoch 00010: val_loss did not improve from 0.26895
# 48963/48963 [==============================] - 38s 782us/sample - loss: 0.1715 - mean_absolute_error: 0.4392 - val_loss: 0.2717 - val_mean_absolute_error: 0.5767
# Epoch 11/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1679 - mean_absolute_error: 0.4339
# Epoch 00011: val_loss did not improve from 0.26895
# 48963/48963 [==============================] - 38s 780us/sample - loss: 0.1679 - mean_absolute_error: 0.4339 - val_loss: 0.2703 - val_mean_absolute_error: 0.5729
# Epoch 12/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1669 - mean_absolute_error: 0.4316
# Epoch 00012: val_loss improved from 0.26895 to 0.26552, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 793us/sample - loss: 0.1668 - mean_absolute_error: 0.4316 - val_loss: 0.2655 - val_mean_absolute_error: 0.5673
# Epoch 13/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.1625 - mean_absolute_error: 0.4251
# Epoch 00013: val_loss did not improve from 0.26552
# 48963/48963 [==============================] - 40s 819us/sample - loss: 0.1625 - mean_absolute_error: 0.4252 - val_loss: 0.2669 - val_mean_absolute_error: 0.5690
# Epoch 14/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1607 - mean_absolute_error: 0.4224
# Epoch 00014: val_loss improved from 0.26552 to 0.26530, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 41s 836us/sample - loss: 0.1607 - mean_absolute_error: 0.4224 - val_loss: 0.2653 - val_mean_absolute_error: 0.5668
# Epoch 15/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1584 - mean_absolute_error: 0.4185
# Epoch 00015: val_loss did not improve from 0.26530
# 48963/48963 [==============================] - 38s 779us/sample - loss: 0.1584 - mean_absolute_error: 0.4185 - val_loss: 0.2663 - val_mean_absolute_error: 0.5679
# Epoch 16/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1568 - mean_absolute_error: 0.4161
# Epoch 00016: val_loss did not improve from 0.26530
# 48963/48963 [==============================] - 39s 795us/sample - loss: 0.1568 - mean_absolute_error: 0.4161 - val_loss: 0.2686 - val_mean_absolute_error: 0.5704
# Epoch 17/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1547 - mean_absolute_error: 0.4131
# Epoch 00017: val_loss did not improve from 0.26530
# 48963/48963 [==============================] - 40s 810us/sample - loss: 0.1547 - mean_absolute_error: 0.4131 - val_loss: 0.2663 - val_mean_absolute_error: 0.5673
# Epoch 18/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.1552 - mean_absolute_error: 0.4138
# Epoch 00018: val_loss did not improve from 0.26530
# 48963/48963 [==============================] - 39s 786us/sample - loss: 0.1553 - mean_absolute_error: 0.4138 - val_loss: 0.2658 - val_mean_absolute_error: 0.5666
# Epoch 19/20
# 48896/48963 [============================>.] - ETA: 0s - loss: 0.1538 - mean_absolute_error: 0.4112
# Epoch 00019: val_loss improved from 0.26530 to 0.26431, saving model to results\2021-12-02_MIXED-640-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 48963/48963 [==============================] - 39s 798us/sample - loss: 0.1538 - mean_absolute_error: 0.4112 - val_loss: 0.2643 - val_mean_absolute_error: 0.5650
# Epoch 20/20
# 48960/48963 [============================>.] - ETA: 0s - loss: 0.1532 - mean_absolute_error: 0.4105
# Epoch 00020: val_loss did not improve from 0.26431
# 48963/48963 [==============================] - 39s 788us/sample - loss: 0.1532 - mean_absolute_error: 0.4105 - val_loss: 0.2659 - val_mean_absolute_error: 0.5671
