# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = 72
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
FEATURE_COLUMNS = ["close_0","ema_0","high_0","low_0","open_0","rsi_0","sma_0","volume_0","close_1","ema_1","high_1","low_1","open_1","rsi_1","sma_1","volume_1",
                   "close_2","ema_2","high_2","low_2","open_2","rsi_2","sma_2","volume_2","close_3","ema_3","high_3","low_3","open_3","rsi_3","sma_3","volume_3",
                   "close_4","ema_4","high_4","low_4","open_4","rsi_4","sma_4","volume_4","close_5","ema_5","high_5","low_5","open_5","rsi_5","sma_5","volume_5",
                   "close_6","ema_6","high_6","low_6","open_6","rsi_6","sma_6","volume_6","close_7","ema_7","high_7","low_7","open_7","rsi_7","sma_7","volume_7",
                   "close_8","ema_8","high_8","low_8","open_8","rsi_8","sma_8","volume_8"]
TARGET_COLUMNS = ["close_9","high_9","low_9","open_9"]
# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "tanh"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv('../data/processed/all_processed_10.csv')

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 67485 samples, validate on 28923 samples
# Epoch 1/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.5288 - mean_absolute_error: 0.9015
# Epoch 00001: val_loss improved from inf to 0.51800, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 43s 632us/sample - loss: 0.5288 - mean_absolute_error: 0.9015 - val_loss: 0.5180 - val_mean_absolute_error: 0.8898
# Epoch 2/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.5182 - mean_absolute_error: 0.8886
# Epoch 00002: val_loss improved from 0.51800 to 0.51674, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 34s 498us/sample - loss: 0.5183 - mean_absolute_error: 0.8887 - val_loss: 0.5167 - val_mean_absolute_error: 0.8889
# Epoch 3/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.5125 - mean_absolute_error: 0.8818
# Epoch 00003: val_loss improved from 0.51674 to 0.50989, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 32s 475us/sample - loss: 0.5126 - mean_absolute_error: 0.8820 - val_loss: 0.5099 - val_mean_absolute_error: 0.8800
# Epoch 4/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.5067 - mean_absolute_error: 0.8750
# Epoch 00004: val_loss improved from 0.50989 to 0.50804, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 32s 476us/sample - loss: 0.5067 - mean_absolute_error: 0.8750 - val_loss: 0.5080 - val_mean_absolute_error: 0.8784
# Epoch 5/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.4995 - mean_absolute_error: 0.8662
# Epoch 00005: val_loss improved from 0.50804 to 0.50126, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 32s 479us/sample - loss: 0.4994 - mean_absolute_error: 0.8662 - val_loss: 0.5013 - val_mean_absolute_error: 0.8698
# Epoch 6/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.4891 - mean_absolute_error: 0.8539
# Epoch 00006: val_loss improved from 0.50126 to 0.50009, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 32s 480us/sample - loss: 0.4891 - mean_absolute_error: 0.8538 - val_loss: 0.5001 - val_mean_absolute_error: 0.8688
# Epoch 7/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.4773 - mean_absolute_error: 0.8392
# Epoch 00007: val_loss improved from 0.50009 to 0.49644, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 35s 512us/sample - loss: 0.4772 - mean_absolute_error: 0.8392 - val_loss: 0.4964 - val_mean_absolute_error: 0.8640
# Epoch 8/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.4623 - mean_absolute_error: 0.8211
# Epoch 00008: val_loss improved from 0.49644 to 0.49143, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 34s 504us/sample - loss: 0.4622 - mean_absolute_error: 0.8210 - val_loss: 0.4914 - val_mean_absolute_error: 0.8580
# Epoch 9/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.4462 - mean_absolute_error: 0.8012
# Epoch 00009: val_loss did not improve from 0.49143
# 67485/67485 [==============================] - 32s 478us/sample - loss: 0.4461 - mean_absolute_error: 0.8012 - val_loss: 0.4916 - val_mean_absolute_error: 0.8581
# Epoch 10/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.4287 - mean_absolute_error: 0.7802
# Epoch 00010: val_loss improved from 0.49143 to 0.48789, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 485us/sample - loss: 0.4286 - mean_absolute_error: 0.7801 - val_loss: 0.4879 - val_mean_absolute_error: 0.8535
# Epoch 11/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.4129 - mean_absolute_error: 0.7598
# Epoch 00011: val_loss improved from 0.48789 to 0.48677, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 484us/sample - loss: 0.4129 - mean_absolute_error: 0.7597 - val_loss: 0.4868 - val_mean_absolute_error: 0.8518
# Epoch 12/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3988 - mean_absolute_error: 0.7425
# Epoch 00012: val_loss did not improve from 0.48677
# 67485/67485 [==============================] - 33s 485us/sample - loss: 0.3988 - mean_absolute_error: 0.7425 - val_loss: 0.4875 - val_mean_absolute_error: 0.8528
# Epoch 13/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3863 - mean_absolute_error: 0.7267
# Epoch 00013: val_loss improved from 0.48677 to 0.48461, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 485us/sample - loss: 0.3863 - mean_absolute_error: 0.7268 - val_loss: 0.4846 - val_mean_absolute_error: 0.8488
# Epoch 14/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3754 - mean_absolute_error: 0.7128
# Epoch 00014: val_loss improved from 0.48461 to 0.48393, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 34s 505us/sample - loss: 0.3755 - mean_absolute_error: 0.7130 - val_loss: 0.4839 - val_mean_absolute_error: 0.8478
# Epoch 15/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3668 - mean_absolute_error: 0.7014
# Epoch 00015: val_loss improved from 0.48393 to 0.48192, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 32s 481us/sample - loss: 0.3668 - mean_absolute_error: 0.7015 - val_loss: 0.4819 - val_mean_absolute_error: 0.8454
# Epoch 16/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3592 - mean_absolute_error: 0.6915
# Epoch 00016: val_loss improved from 0.48192 to 0.48150, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 491us/sample - loss: 0.3592 - mean_absolute_error: 0.6915 - val_loss: 0.4815 - val_mean_absolute_error: 0.8447
# Epoch 17/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3532 - mean_absolute_error: 0.6843
# Epoch 00017: val_loss did not improve from 0.48150
# 67485/67485 [==============================] - 33s 490us/sample - loss: 0.3532 - mean_absolute_error: 0.6843 - val_loss: 0.4850 - val_mean_absolute_error: 0.8488
# Epoch 18/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3487 - mean_absolute_error: 0.6778
# Epoch 00018: val_loss improved from 0.48150 to 0.47952, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 485us/sample - loss: 0.3485 - mean_absolute_error: 0.6776 - val_loss: 0.4795 - val_mean_absolute_error: 0.8418
# Epoch 19/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3444 - mean_absolute_error: 0.6722
# Epoch 00019: val_loss did not improve from 0.47952
# 67485/67485 [==============================] - 33s 482us/sample - loss: 0.3444 - mean_absolute_error: 0.6722 - val_loss: 0.4804 - val_mean_absolute_error: 0.8429
# Epoch 20/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3395 - mean_absolute_error: 0.6658
# Epoch 00020: val_loss did not improve from 0.47952
# 67485/67485 [==============================] - 32s 481us/sample - loss: 0.3396 - mean_absolute_error: 0.6658 - val_loss: 0.4797 - val_mean_absolute_error: 0.8421
# Epoch 21/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3375 - mean_absolute_error: 0.6628
# Epoch 00021: val_loss improved from 0.47952 to 0.47716, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 488us/sample - loss: 0.3374 - mean_absolute_error: 0.6627 - val_loss: 0.4772 - val_mean_absolute_error: 0.8393
# Epoch 22/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3349 - mean_absolute_error: 0.6590
# Epoch 00022: val_loss did not improve from 0.47716
# 67485/67485 [==============================] - 33s 487us/sample - loss: 0.3349 - mean_absolute_error: 0.6590 - val_loss: 0.4798 - val_mean_absolute_error: 0.8424
# Epoch 23/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3322 - mean_absolute_error: 0.6555
# Epoch 00023: val_loss improved from 0.47716 to 0.47594, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 494us/sample - loss: 0.3322 - mean_absolute_error: 0.6554 - val_loss: 0.4759 - val_mean_absolute_error: 0.8371
# Epoch 24/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3299 - mean_absolute_error: 0.6523
# Epoch 00024: val_loss did not improve from 0.47594
# 67485/67485 [==============================] - 33s 490us/sample - loss: 0.3298 - mean_absolute_error: 0.6523 - val_loss: 0.4798 - val_mean_absolute_error: 0.8422
# Epoch 25/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3285 - mean_absolute_error: 0.6504
# Epoch 00025: val_loss did not improve from 0.47594
# 67485/67485 [==============================] - 33s 486us/sample - loss: 0.3286 - mean_absolute_error: 0.6506 - val_loss: 0.4775 - val_mean_absolute_error: 0.8392
# Epoch 26/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3267 - mean_absolute_error: 0.6478
# Epoch 00026: val_loss did not improve from 0.47594
# 67485/67485 [==============================] - 33s 485us/sample - loss: 0.3267 - mean_absolute_error: 0.6477 - val_loss: 0.4770 - val_mean_absolute_error: 0.8382
# Epoch 27/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3260 - mean_absolute_error: 0.6471
# Epoch 00027: val_loss did not improve from 0.47594
# 67485/67485 [==============================] - 32s 481us/sample - loss: 0.3262 - mean_absolute_error: 0.6473 - val_loss: 0.4786 - val_mean_absolute_error: 0.8403
# Epoch 28/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3247 - mean_absolute_error: 0.6447
# Epoch 00028: val_loss did not improve from 0.47594
# 67485/67485 [==============================] - 33s 483us/sample - loss: 0.3246 - mean_absolute_error: 0.6446 - val_loss: 0.4765 - val_mean_absolute_error: 0.8376
# Epoch 29/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3226 - mean_absolute_error: 0.6420
# Epoch 00029: val_loss did not improve from 0.47594
# 67485/67485 [==============================] - 33s 485us/sample - loss: 0.3225 - mean_absolute_error: 0.6419 - val_loss: 0.4784 - val_mean_absolute_error: 0.8397
# Epoch 30/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3212 - mean_absolute_error: 0.6401
# Epoch 00030: val_loss improved from 0.47594 to 0.47560, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 488us/sample - loss: 0.3212 - mean_absolute_error: 0.6400 - val_loss: 0.4756 - val_mean_absolute_error: 0.8364
# Epoch 31/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3210 - mean_absolute_error: 0.6401
# Epoch 00031: val_loss improved from 0.47560 to 0.47543, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 486us/sample - loss: 0.3210 - mean_absolute_error: 0.6401 - val_loss: 0.4754 - val_mean_absolute_error: 0.8361
# Epoch 32/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3199 - mean_absolute_error: 0.6383
# Epoch 00032: val_loss improved from 0.47543 to 0.47442, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 490us/sample - loss: 0.3199 - mean_absolute_error: 0.6383 - val_loss: 0.4744 - val_mean_absolute_error: 0.8349
# Epoch 33/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3199 - mean_absolute_error: 0.6383
# Epoch 00033: val_loss did not improve from 0.47442
# 67485/67485 [==============================] - 33s 486us/sample - loss: 0.3200 - mean_absolute_error: 0.6384 - val_loss: 0.4753 - val_mean_absolute_error: 0.8362
# Epoch 34/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3191 - mean_absolute_error: 0.6372
# Epoch 00034: val_loss improved from 0.47442 to 0.47415, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 489us/sample - loss: 0.3190 - mean_absolute_error: 0.6371 - val_loss: 0.4741 - val_mean_absolute_error: 0.8348
# Epoch 35/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3178 - mean_absolute_error: 0.6351
# Epoch 00035: val_loss did not improve from 0.47415
# 67485/67485 [==============================] - 32s 482us/sample - loss: 0.3177 - mean_absolute_error: 0.6350 - val_loss: 0.4760 - val_mean_absolute_error: 0.8370
# Epoch 36/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3167 - mean_absolute_error: 0.6334
# Epoch 00036: val_loss did not improve from 0.47415
# 67485/67485 [==============================] - 32s 480us/sample - loss: 0.3167 - mean_absolute_error: 0.6334 - val_loss: 0.4743 - val_mean_absolute_error: 0.8350
# Epoch 37/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3162 - mean_absolute_error: 0.6328
# Epoch 00037: val_loss did not improve from 0.47415
# 67485/67485 [==============================] - 32s 480us/sample - loss: 0.3162 - mean_absolute_error: 0.6328 - val_loss: 0.4742 - val_mean_absolute_error: 0.8344
# Epoch 38/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3159 - mean_absolute_error: 0.6325
# Epoch 00038: val_loss improved from 0.47415 to 0.47329, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 487us/sample - loss: 0.3159 - mean_absolute_error: 0.6325 - val_loss: 0.4733 - val_mean_absolute_error: 0.8334
# Epoch 39/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3148 - mean_absolute_error: 0.6309
# Epoch 00039: val_loss did not improve from 0.47329
# 67485/67485 [==============================] - 33s 483us/sample - loss: 0.3149 - mean_absolute_error: 0.6309 - val_loss: 0.4750 - val_mean_absolute_error: 0.8352
# Epoch 40/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3146 - mean_absolute_error: 0.6304
# Epoch 00040: val_loss improved from 0.47329 to 0.47229, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 33s 493us/sample - loss: 0.3145 - mean_absolute_error: 0.6303 - val_loss: 0.4723 - val_mean_absolute_error: 0.8319
# Epoch 41/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3139 - mean_absolute_error: 0.6295
# Epoch 00041: val_loss did not improve from 0.47229
# 67485/67485 [==============================] - 38s 567us/sample - loss: 0.3138 - mean_absolute_error: 0.6295 - val_loss: 0.4731 - val_mean_absolute_error: 0.8332
# Epoch 42/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3139 - mean_absolute_error: 0.6297
# Epoch 00042: val_loss did not improve from 0.47229
# 67485/67485 [==============================] - 34s 502us/sample - loss: 0.3141 - mean_absolute_error: 0.6299 - val_loss: 0.4727 - val_mean_absolute_error: 0.8330
# Epoch 43/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3133 - mean_absolute_error: 0.6285
# Epoch 00043: val_loss did not improve from 0.47229
# 67485/67485 [==============================] - 34s 497us/sample - loss: 0.3132 - mean_absolute_error: 0.6284 - val_loss: 0.4728 - val_mean_absolute_error: 0.8325
# Epoch 44/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3131 - mean_absolute_error: 0.6283
# Epoch 00044: val_loss did not improve from 0.47229
# 67485/67485 [==============================] - 34s 501us/sample - loss: 0.3132 - mean_absolute_error: 0.6283 - val_loss: 0.4735 - val_mean_absolute_error: 0.8334
# Epoch 45/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3124 - mean_absolute_error: 0.6275
# Epoch 00045: val_loss improved from 0.47229 to 0.47139, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 34s 504us/sample - loss: 0.3124 - mean_absolute_error: 0.6275 - val_loss: 0.4714 - val_mean_absolute_error: 0.8309
# Epoch 46/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3124 - mean_absolute_error: 0.6271
# Epoch 00046: val_loss did not improve from 0.47139
# 67485/67485 [==============================] - 34s 502us/sample - loss: 0.3124 - mean_absolute_error: 0.6272 - val_loss: 0.4723 - val_mean_absolute_error: 0.8312
# Epoch 47/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3119 - mean_absolute_error: 0.6264
# Epoch 00047: val_loss did not improve from 0.47139
# 67485/67485 [==============================] - 34s 498us/sample - loss: 0.3118 - mean_absolute_error: 0.6264 - val_loss: 0.4720 - val_mean_absolute_error: 0.8314
# Epoch 48/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3119 - mean_absolute_error: 0.6263
# Epoch 00048: val_loss improved from 0.47139 to 0.47080, saving model to results\2021-12-01_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67485/67485 [==============================] - 34s 499us/sample - loss: 0.3118 - mean_absolute_error: 0.6263 - val_loss: 0.4708 - val_mean_absolute_error: 0.8302
# Epoch 49/50
# 67456/67485 [============================>.] - ETA: 0s - loss: 0.3110 - mean_absolute_error: 0.6251
# Epoch 00049: val_loss did not improve from 0.47080
# 67485/67485 [==============================] - 34s 497us/sample - loss: 0.3110 - mean_absolute_error: 0.6251 - val_loss: 0.4723 - val_mean_absolute_error: 0.8316
# Epoch 50/50
# 67392/67485 [============================>.] - ETA: 0s - loss: 0.3100 - mean_absolute_error: 0.6238
# Epoch 00050: val_loss did not improve from 0.47080
# 67485/67485 [==============================] - 34s 500us/sample - loss: 0.3100 - mean_absolute_error: 0.6238 - val_loss: 0.4709 - val_mean_absolute_error: 0.8304

# %%
# list all data in history
print(history.history.keys())

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])
