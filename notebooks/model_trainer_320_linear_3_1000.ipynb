# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(4, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 320

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 25

LAYER_ACTIVATION = "linear"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 61009 samples, validate on 26148 samples
# Epoch 1/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00001: val_loss improved from inf to 0.32096, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 49s 808us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.3210 - val_mean_absolute_error: 0.6468
# Epoch 2/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00002: val_loss improved from 0.32096 to 0.28817, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 40s 650us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2882 - val_mean_absolute_error: 0.6055
# Epoch 3/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00003: val_loss improved from 0.28817 to 0.26660, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 639us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2666 - val_mean_absolute_error: 0.5770
# Epoch 4/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00004: val_loss improved from 0.26660 to 0.25005, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 618us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2500 - val_mean_absolute_error: 0.5538
# Epoch 5/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00005: val_loss did not improve from 0.25005
# 61009/61009 [==============================] - 37s 609us/sample - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 6/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00006: val_loss improved from 0.25005 to 0.23632, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 617us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2363 - val_mean_absolute_error: 0.5356
# Epoch 7/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00007: val_loss improved from 0.23632 to 0.23495, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 616us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2349 - val_mean_absolute_error: 0.5334
# Epoch 8/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00008: val_loss improved from 0.23495 to 0.23069, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 615us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2307 - val_mean_absolute_error: 0.5265
# Epoch 9/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00009: val_loss improved from 0.23069 to 0.22845, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 617us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2285 - val_mean_absolute_error: 0.5235
# Epoch 10/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00010: val_loss improved from 0.22845 to 0.22464, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 615us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2246 - val_mean_absolute_error: 0.5184
# Epoch 11/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00011: val_loss improved from 0.22464 to 0.22282, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 621us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2228 - val_mean_absolute_error: 0.5143
# Epoch 12/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00012: val_loss improved from 0.22282 to 0.22243, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 617us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2224 - val_mean_absolute_error: 0.5146
# Epoch 13/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00013: val_loss improved from 0.22243 to 0.22161, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 620us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2216 - val_mean_absolute_error: 0.5128
# Epoch 14/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00014: val_loss improved from 0.22161 to 0.21927, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 629us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2193 - val_mean_absolute_error: 0.5088
# Epoch 15/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00015: val_loss improved from 0.21927 to 0.21824, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 627us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2182 - val_mean_absolute_error: 0.5077
# Epoch 16/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00016: val_loss did not improve from 0.21824
# 61009/61009 [==============================] - 39s 637us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2190 - val_mean_absolute_error: 0.5076
# Epoch 17/25
# 60928/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00017: val_loss improved from 0.21824 to 0.21701, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 39s 635us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2170 - val_mean_absolute_error: 0.5046
# Epoch 18/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00018: val_loss did not improve from 0.21701
# 61009/61009 [==============================] - 38s 622us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2178 - val_mean_absolute_error: 0.5053
# Epoch 19/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00019: val_loss improved from 0.21701 to 0.21668, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 626us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2167 - val_mean_absolute_error: 0.5026
# Epoch 20/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00020: val_loss improved from 0.21668 to 0.21607, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 625us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2161 - val_mean_absolute_error: 0.5034
# Epoch 21/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00021: val_loss improved from 0.21607 to 0.21488, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 624us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2149 - val_mean_absolute_error: 0.5017
# Epoch 22/25
# 60928/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00022: val_loss did not improve from 0.21488
# 61009/61009 [==============================] - 38s 618us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2171 - val_mean_absolute_error: 0.5033
# Epoch 23/25
# 60928/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00023: val_loss did not improve from 0.21488
# 61009/61009 [==============================] - 38s 622us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2162 - val_mean_absolute_error: 0.5028
# Epoch 24/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00024: val_loss did not improve from 0.21488
# 61009/61009 [==============================] - 38s 619us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2157 - val_mean_absolute_error: 0.5015
# Epoch 25/25
# 60992/61009 [============================>.] - ETA: 0s - loss: nan - mean_absolute_error: nan
# Epoch 00025: val_loss improved from 0.21488 to 0.21364, saving model to results\2021-12-03_MIXED-320-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 61009/61009 [==============================] - 38s 624us/sample - loss: nan - mean_absolute_error: nan - val_loss: 0.2136 - val_mean_absolute_error: 0.4991
