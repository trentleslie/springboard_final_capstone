# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 160

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "linear"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 63075 samples, validate on 27033 samples
# Epoch 1/50
# 62976/63075 [============================>.] - ETA: 0s - loss: 0.3812 - mean_absolute_error: 0.7242
# Epoch 00001: val_loss improved from inf to 0.34574, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 47s 741us/sample - loss: 0.3810 - mean_absolute_error: 0.7240 - val_loss: 0.3457 - val_mean_absolute_error: 0.6833
# Epoch 2/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.3213 - mean_absolute_error: 0.6507
# Epoch 00002: val_loss improved from 0.34574 to 0.31393, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 38s 599us/sample - loss: 0.3213 - mean_absolute_error: 0.6507 - val_loss: 0.3139 - val_mean_absolute_error: 0.6424
# Epoch 3/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.2737 - mean_absolute_error: 0.5886
# Epoch 00003: val_loss improved from 0.31393 to 0.29486, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 37s 579us/sample - loss: 0.2737 - mean_absolute_error: 0.5886 - val_loss: 0.2949 - val_mean_absolute_error: 0.6174
# Epoch 4/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.2409 - mean_absolute_error: 0.5456
# Epoch 00004: val_loss improved from 0.29486 to 0.28579, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 578us/sample - loss: 0.2409 - mean_absolute_error: 0.5456 - val_loss: 0.2858 - val_mean_absolute_error: 0.6052
# Epoch 5/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.2224 - mean_absolute_error: 0.5199
# Epoch 00005: val_loss improved from 0.28579 to 0.28377, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 576us/sample - loss: 0.2224 - mean_absolute_error: 0.5200 - val_loss: 0.2838 - val_mean_absolute_error: 0.6038
# Epoch 6/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.2081 - mean_absolute_error: 0.4998
# Epoch 00006: val_loss improved from 0.28377 to 0.28228, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 577us/sample - loss: 0.2081 - mean_absolute_error: 0.4998 - val_loss: 0.2823 - val_mean_absolute_error: 0.6015
# Epoch 7/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1987 - mean_absolute_error: 0.4864
# Epoch 00007: val_loss improved from 0.28228 to 0.27470, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 577us/sample - loss: 0.1987 - mean_absolute_error: 0.4864 - val_loss: 0.2747 - val_mean_absolute_error: 0.5904
# Epoch 8/50
# 62976/63075 [============================>.] - ETA: 0s - loss: 0.1924 - mean_absolute_error: 0.4773
# Epoch 00008: val_loss did not improve from 0.27470
# 63075/63075 [==============================] - 36s 576us/sample - loss: 0.1924 - mean_absolute_error: 0.4773 - val_loss: 0.2747 - val_mean_absolute_error: 0.5908
# Epoch 9/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1867 - mean_absolute_error: 0.4691
# Epoch 00009: val_loss improved from 0.27470 to 0.27116, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 576us/sample - loss: 0.1867 - mean_absolute_error: 0.4690 - val_loss: 0.2712 - val_mean_absolute_error: 0.5852
# Epoch 10/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1824 - mean_absolute_error: 0.4621
# Epoch 00010: val_loss did not improve from 0.27116
# 63075/63075 [==============================] - 36s 572us/sample - loss: 0.1824 - mean_absolute_error: 0.4621 - val_loss: 0.2722 - val_mean_absolute_error: 0.5861
# Epoch 11/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1785 - mean_absolute_error: 0.4562
# Epoch 00011: val_loss improved from 0.27116 to 0.27092, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 576us/sample - loss: 0.1785 - mean_absolute_error: 0.4562 - val_loss: 0.2709 - val_mean_absolute_error: 0.5845
# Epoch 12/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1764 - mean_absolute_error: 0.4534
# Epoch 00012: val_loss improved from 0.27092 to 0.26937, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 36s 576us/sample - loss: 0.1764 - mean_absolute_error: 0.4534 - val_loss: 0.2694 - val_mean_absolute_error: 0.5819
# Epoch 13/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1742 - mean_absolute_error: 0.4499
# Epoch 00013: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 575us/sample - loss: 0.1742 - mean_absolute_error: 0.4499 - val_loss: 0.2707 - val_mean_absolute_error: 0.5834
# Epoch 14/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1732 - mean_absolute_error: 0.4482
# Epoch 00014: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 574us/sample - loss: 0.1732 - mean_absolute_error: 0.4482 - val_loss: 0.2732 - val_mean_absolute_error: 0.5865
# Epoch 15/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1722 - mean_absolute_error: 0.4470
# Epoch 00015: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 572us/sample - loss: 0.1722 - mean_absolute_error: 0.4470 - val_loss: 0.2734 - val_mean_absolute_error: 0.5866
# Epoch 16/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1698 - mean_absolute_error: 0.4427
# Epoch 00016: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 572us/sample - loss: 0.1697 - mean_absolute_error: 0.4427 - val_loss: 0.2725 - val_mean_absolute_error: 0.5843
# Epoch 17/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1687 - mean_absolute_error: 0.4403
# Epoch 00017: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1687 - mean_absolute_error: 0.4403 - val_loss: 0.2706 - val_mean_absolute_error: 0.5833
# Epoch 18/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1670 - mean_absolute_error: 0.4385
# Epoch 00018: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 575us/sample - loss: 0.1670 - mean_absolute_error: 0.4385 - val_loss: 0.2724 - val_mean_absolute_error: 0.5844
# Epoch 19/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1634 - mean_absolute_error: 0.4326
# Epoch 00019: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1634 - mean_absolute_error: 0.4327 - val_loss: 0.2718 - val_mean_absolute_error: 0.5840
# Epoch 20/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1633 - mean_absolute_error: 0.4322
# Epoch 00020: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 576us/sample - loss: 0.1633 - mean_absolute_error: 0.4323 - val_loss: 0.2705 - val_mean_absolute_error: 0.5817
# Epoch 21/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1620 - mean_absolute_error: 0.4305
# Epoch 00021: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1621 - mean_absolute_error: 0.4306 - val_loss: 0.2711 - val_mean_absolute_error: 0.5821
# Epoch 22/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1615 - mean_absolute_error: 0.4291
# Epoch 00022: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 572us/sample - loss: 0.1616 - mean_absolute_error: 0.4291 - val_loss: 0.2699 - val_mean_absolute_error: 0.5809
# Epoch 23/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1610 - mean_absolute_error: 0.4289
# Epoch 00023: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1610 - mean_absolute_error: 0.4289 - val_loss: 0.2710 - val_mean_absolute_error: 0.5829
# Epoch 24/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1619 - mean_absolute_error: 0.4302
# Epoch 00024: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1620 - mean_absolute_error: 0.4303 - val_loss: 0.2720 - val_mean_absolute_error: 0.5832
# Epoch 25/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1615 - mean_absolute_error: 0.4294
# Epoch 00025: val_loss did not improve from 0.26937
# 63075/63075 [==============================] - 36s 570us/sample - loss: 0.1615 - mean_absolute_error: 0.4294 - val_loss: 0.2704 - val_mean_absolute_error: 0.5818
# Epoch 26/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1580 - mean_absolute_error: 0.4239
# Epoch 00026: val_loss improved from 0.26937 to 0.26890, saving model to results\2021-12-02_MIXED-160-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 63075/63075 [==============================] - 38s 608us/sample - loss: 0.1580 - mean_absolute_error: 0.4239 - val_loss: 0.2689 - val_mean_absolute_error: 0.5796
# Epoch 27/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1566 - mean_absolute_error: 0.4216
# Epoch 00027: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 37s 584us/sample - loss: 0.1566 - mean_absolute_error: 0.4216 - val_loss: 0.2755 - val_mean_absolute_error: 0.5863
# Epoch 28/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1562 - mean_absolute_error: 0.4215
# Epoch 00028: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 578us/sample - loss: 0.1562 - mean_absolute_error: 0.4215 - val_loss: 0.2746 - val_mean_absolute_error: 0.5864
# Epoch 29/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1550 - mean_absolute_error: 0.4200
# Epoch 00029: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1551 - mean_absolute_error: 0.4200 - val_loss: 0.2723 - val_mean_absolute_error: 0.5836
# Epoch 30/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1554 - mean_absolute_error: 0.4206
# Epoch 00030: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 37s 580us/sample - loss: 0.1554 - mean_absolute_error: 0.4206 - val_loss: 0.2698 - val_mean_absolute_error: 0.5800
# Epoch 31/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1555 - mean_absolute_error: 0.4200
# Epoch 00031: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 569us/sample - loss: 0.1555 - mean_absolute_error: 0.4199 - val_loss: 0.2744 - val_mean_absolute_error: 0.5852
# Epoch 32/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1534 - mean_absolute_error: 0.4177
# Epoch 00032: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1534 - mean_absolute_error: 0.4177 - val_loss: 0.2777 - val_mean_absolute_error: 0.5884
# Epoch 33/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1544 - mean_absolute_error: 0.4180
# Epoch 00033: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 575us/sample - loss: 0.1544 - mean_absolute_error: 0.4179 - val_loss: 0.2751 - val_mean_absolute_error: 0.5850
# Epoch 34/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1521 - mean_absolute_error: 0.4152
# Epoch 00034: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 570us/sample - loss: 0.1520 - mean_absolute_error: 0.4151 - val_loss: 0.2744 - val_mean_absolute_error: 0.5843
# Epoch 35/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1515 - mean_absolute_error: 0.4142
# Epoch 00035: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1515 - mean_absolute_error: 0.4141 - val_loss: 0.2725 - val_mean_absolute_error: 0.5823
# Epoch 36/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1520 - mean_absolute_error: 0.4151
# Epoch 00036: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 572us/sample - loss: 0.1520 - mean_absolute_error: 0.4151 - val_loss: 0.2736 - val_mean_absolute_error: 0.5836
# Epoch 37/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1520 - mean_absolute_error: 0.4146
# Epoch 00037: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 570us/sample - loss: 0.1520 - mean_absolute_error: 0.4145 - val_loss: 0.2722 - val_mean_absolute_error: 0.5825
# Epoch 38/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1506 - mean_absolute_error: 0.4126
# Epoch 00038: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1506 - mean_absolute_error: 0.4126 - val_loss: 0.2717 - val_mean_absolute_error: 0.5820
# Epoch 39/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1507 - mean_absolute_error: 0.4127
# Epoch 00039: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1507 - mean_absolute_error: 0.4127 - val_loss: 0.2736 - val_mean_absolute_error: 0.5840
# Epoch 40/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1507 - mean_absolute_error: 0.4127
# Epoch 00040: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1507 - mean_absolute_error: 0.4127 - val_loss: 0.2717 - val_mean_absolute_error: 0.5822
# Epoch 41/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1500 - mean_absolute_error: 0.4119
# Epoch 00041: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 570us/sample - loss: 0.1499 - mean_absolute_error: 0.4118 - val_loss: 0.2784 - val_mean_absolute_error: 0.5890
# Epoch 42/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1513 - mean_absolute_error: 0.4134
# Epoch 00042: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1513 - mean_absolute_error: 0.4134 - val_loss: 0.2721 - val_mean_absolute_error: 0.5825
# Epoch 43/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1490 - mean_absolute_error: 0.4104
# Epoch 00043: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 574us/sample - loss: 0.1490 - mean_absolute_error: 0.4104 - val_loss: 0.2733 - val_mean_absolute_error: 0.5837
# Epoch 44/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1500 - mean_absolute_error: 0.4114
# Epoch 00044: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 570us/sample - loss: 0.1500 - mean_absolute_error: 0.4114 - val_loss: 0.2756 - val_mean_absolute_error: 0.5870
# Epoch 45/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1491 - mean_absolute_error: 0.4103
# Epoch 00045: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 573us/sample - loss: 0.1491 - mean_absolute_error: 0.4103 - val_loss: 0.2731 - val_mean_absolute_error: 0.5835
# Epoch 46/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1489 - mean_absolute_error: 0.4097
# Epoch 00046: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1489 - mean_absolute_error: 0.4097 - val_loss: 0.2772 - val_mean_absolute_error: 0.5871
# Epoch 47/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1480 - mean_absolute_error: 0.4088
# Epoch 00047: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 571us/sample - loss: 0.1481 - mean_absolute_error: 0.4088 - val_loss: 0.2711 - val_mean_absolute_error: 0.5815
# Epoch 48/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1484 - mean_absolute_error: 0.4088
# Epoch 00048: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 575us/sample - loss: 0.1484 - mean_absolute_error: 0.4088 - val_loss: 0.2751 - val_mean_absolute_error: 0.5857
# Epoch 49/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1482 - mean_absolute_error: 0.4086
# Epoch 00049: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 36s 572us/sample - loss: 0.1482 - mean_absolute_error: 0.4086 - val_loss: 0.2738 - val_mean_absolute_error: 0.5842
# Epoch 50/50
# 63040/63075 [============================>.] - ETA: 0s - loss: 0.1468 - mean_absolute_error: 0.4064
# Epoch 00050: val_loss did not improve from 0.26890
# 63075/63075 [==============================] - 35s 554us/sample - loss: 0.1468 - mean_absolute_error: 0.4065 - val_loss: 0.2740 - val_mean_absolute_error: 0.5839
