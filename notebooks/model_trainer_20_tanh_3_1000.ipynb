# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = 152
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
FEATURE_COLUMNS = ["close_0","ema_0","high_0","low_0","open_0","rsi_0","sma_0","volume_0","close_1","ema_1","high_1","low_1","open_1","rsi_1","sma_1","volume_1",
                   "close_2","ema_2","high_2","low_2","open_2","rsi_2","sma_2","volume_2","close_3","ema_3","high_3","low_3","open_3","rsi_3","sma_3","volume_3",
                   "close_4","ema_4","high_4","low_4","open_4","rsi_4","sma_4","volume_4","close_5","ema_5","high_5","low_5","open_5","rsi_5","sma_5","volume_5",
                   "close_6","ema_6","high_6","low_6","open_6","rsi_6","sma_6","volume_6","close_7","ema_7","high_7","low_7","open_7","rsi_7","sma_7","volume_7",
                   "close_8","ema_8","high_8","low_8","open_8","rsi_8","sma_8","volume_8","close_9","ema_9","high_9","low_9","open_9","rsi_9","sma_9","volume_9",
                   "close_10","ema_10","high_10","low_10","open_10","rsi_10","sma_10","volume_10","close_11","ema_11","high_11","low_11","open_11","rsi_11","sma_11","volume_11",
                   "close_12","ema_12","high_12","low_12","open_12","rsi_12","sma_12","volume_12","close_13","ema_13","high_13","low_13","open_13","rsi_13","sma_13","volume_13",
                   "close_14","ema_14","high_14","low_14","open_14","rsi_14","sma_14","volume_14","close_15","ema_15","high_15","low_15","open_15","rsi_15","sma_15","volume_15",
                   "close_16","ema_16","high_16","low_16","open_16","rsi_16","sma_16","volume_16","close_17","ema_17","high_17","low_17","open_17","rsi_17","sma_17","volume_17",
                   "close_18","ema_18","high_18","low_18","open_18","rsi_18","sma_18","volume_18"]
TARGET_COLUMNS = ["close_19","high_19","low_19","open_19"]
# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "tanh"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv('../data/processed/all_processed_20.csv')

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 67191 samples, validate on 28797 samples
# Epoch 1/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4523 - mean_absolute_error: 0.8149
# Epoch 00001: val_loss improved from inf to 0.43679, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 91s 1ms/sample - loss: 0.4522 - mean_absolute_error: 0.8148 - val_loss: 0.4368 - val_mean_absolute_error: 0.7960
# Epoch 2/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4377 - mean_absolute_error: 0.7973
# Epoch 00002: val_loss improved from 0.43679 to 0.43100, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 66s 981us/sample - loss: 0.4377 - mean_absolute_error: 0.7974 - val_loss: 0.4310 - val_mean_absolute_error: 0.7888
# Epoch 3/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4248 - mean_absolute_error: 0.7815
# Epoch 00003: val_loss improved from 0.43100 to 0.42268, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 60s 900us/sample - loss: 0.4248 - mean_absolute_error: 0.7815 - val_loss: 0.4227 - val_mean_absolute_error: 0.7780
# Epoch 4/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4083 - mean_absolute_error: 0.7608
# Epoch 00004: val_loss improved from 0.42268 to 0.41442, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 61s 905us/sample - loss: 0.4083 - mean_absolute_error: 0.7608 - val_loss: 0.4144 - val_mean_absolute_error: 0.7680
# Epoch 5/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3888 - mean_absolute_error: 0.7359
# Epoch 00005: val_loss improved from 0.41442 to 0.40623, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 60s 900us/sample - loss: 0.3888 - mean_absolute_error: 0.7359 - val_loss: 0.4062 - val_mean_absolute_error: 0.7576
# Epoch 6/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3665 - mean_absolute_error: 0.7075
# Epoch 00006: val_loss improved from 0.40623 to 0.40078, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 60s 899us/sample - loss: 0.3664 - mean_absolute_error: 0.7075 - val_loss: 0.4008 - val_mean_absolute_error: 0.7508
# Epoch 7/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3447 - mean_absolute_error: 0.6795
# Epoch 00007: val_loss improved from 0.40078 to 0.39402, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 64s 952us/sample - loss: 0.3447 - mean_absolute_error: 0.6796 - val_loss: 0.3940 - val_mean_absolute_error: 0.7419
# Epoch 8/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3226 - mean_absolute_error: 0.6510
# Epoch 00008: val_loss improved from 0.39402 to 0.39027, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 60s 892us/sample - loss: 0.3227 - mean_absolute_error: 0.6511 - val_loss: 0.3903 - val_mean_absolute_error: 0.7372
# Epoch 9/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3060 - mean_absolute_error: 0.6293
# Epoch 00009: val_loss improved from 0.39027 to 0.38810, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 62s 929us/sample - loss: 0.3059 - mean_absolute_error: 0.6293 - val_loss: 0.3881 - val_mean_absolute_error: 0.7345
# Epoch 10/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2947 - mean_absolute_error: 0.6142
# Epoch 00010: val_loss improved from 0.38810 to 0.38663, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 64s 948us/sample - loss: 0.2947 - mean_absolute_error: 0.6142 - val_loss: 0.3866 - val_mean_absolute_error: 0.7327
# Epoch 11/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2842 - mean_absolute_error: 0.6000
# Epoch 00011: val_loss improved from 0.38663 to 0.38509, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 63s 935us/sample - loss: 0.2842 - mean_absolute_error: 0.6000 - val_loss: 0.3851 - val_mean_absolute_error: 0.7302
# Epoch 12/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2764 - mean_absolute_error: 0.5892
# Epoch 00012: val_loss improved from 0.38509 to 0.38290, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 58s 859us/sample - loss: 0.2764 - mean_absolute_error: 0.5892 - val_loss: 0.3829 - val_mean_absolute_error: 0.7273
# Epoch 13/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2719 - mean_absolute_error: 0.5827
# Epoch 00013: val_loss improved from 0.38290 to 0.37980, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 59s 880us/sample - loss: 0.2719 - mean_absolute_error: 0.5827 - val_loss: 0.3798 - val_mean_absolute_error: 0.7232
# Epoch 14/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2668 - mean_absolute_error: 0.5760
# Epoch 00014: val_loss improved from 0.37980 to 0.37975, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 829us/sample - loss: 0.2668 - mean_absolute_error: 0.5759 - val_loss: 0.3797 - val_mean_absolute_error: 0.7219
# Epoch 15/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2632 - mean_absolute_error: 0.5706
# Epoch 00015: val_loss improved from 0.37975 to 0.37879, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 839us/sample - loss: 0.2632 - mean_absolute_error: 0.5706 - val_loss: 0.3788 - val_mean_absolute_error: 0.7218
# Epoch 16/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2623 - mean_absolute_error: 0.5687
# Epoch 00016: val_loss did not improve from 0.37879
# 67191/67191 [==============================] - 56s 832us/sample - loss: 0.2622 - mean_absolute_error: 0.5686 - val_loss: 0.3796 - val_mean_absolute_error: 0.7228
# Epoch 17/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2590 - mean_absolute_error: 0.5643
# Epoch 00017: val_loss improved from 0.37879 to 0.37697, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 829us/sample - loss: 0.2590 - mean_absolute_error: 0.5643 - val_loss: 0.3770 - val_mean_absolute_error: 0.7188
# Epoch 18/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2567 - mean_absolute_error: 0.5606
# Epoch 00018: val_loss did not improve from 0.37697
# 67191/67191 [==============================] - 56s 831us/sample - loss: 0.2566 - mean_absolute_error: 0.5606 - val_loss: 0.3773 - val_mean_absolute_error: 0.7191
# Epoch 19/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2565 - mean_absolute_error: 0.5601
# Epoch 00019: val_loss did not improve from 0.37697
# 67191/67191 [==============================] - 56s 835us/sample - loss: 0.2565 - mean_absolute_error: 0.5601 - val_loss: 0.3772 - val_mean_absolute_error: 0.7193
# Epoch 20/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2538 - mean_absolute_error: 0.5562
# Epoch 00020: val_loss improved from 0.37697 to 0.37660, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 841us/sample - loss: 0.2538 - mean_absolute_error: 0.5563 - val_loss: 0.3766 - val_mean_absolute_error: 0.7189
# Epoch 21/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2538 - mean_absolute_error: 0.5560
# Epoch 00021: val_loss improved from 0.37660 to 0.37455, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 831us/sample - loss: 0.2538 - mean_absolute_error: 0.5560 - val_loss: 0.3746 - val_mean_absolute_error: 0.7153
# Epoch 22/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2526 - mean_absolute_error: 0.5547
# Epoch 00022: val_loss did not improve from 0.37455
# 67191/67191 [==============================] - 56s 830us/sample - loss: 0.2526 - mean_absolute_error: 0.5547 - val_loss: 0.3769 - val_mean_absolute_error: 0.7181
# Epoch 23/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2513 - mean_absolute_error: 0.5525
# Epoch 00023: val_loss did not improve from 0.37455
# 67191/67191 [==============================] - 55s 823us/sample - loss: 0.2513 - mean_absolute_error: 0.5525 - val_loss: 0.3749 - val_mean_absolute_error: 0.7161
# Epoch 24/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2501 - mean_absolute_error: 0.5508
# Epoch 00024: val_loss did not improve from 0.37455
# 67191/67191 [==============================] - 55s 826us/sample - loss: 0.2500 - mean_absolute_error: 0.5507 - val_loss: 0.3749 - val_mean_absolute_error: 0.7162
# Epoch 25/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2490 - mean_absolute_error: 0.5492
# Epoch 00025: val_loss did not improve from 0.37455
# 67191/67191 [==============================] - 55s 826us/sample - loss: 0.2491 - mean_absolute_error: 0.5493 - val_loss: 0.3751 - val_mean_absolute_error: 0.7163
# Epoch 26/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2491 - mean_absolute_error: 0.5490
# Epoch 00026: val_loss improved from 0.37455 to 0.37356, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 835us/sample - loss: 0.2492 - mean_absolute_error: 0.5490 - val_loss: 0.3736 - val_mean_absolute_error: 0.7142
# Epoch 27/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2480 - mean_absolute_error: 0.5474
# Epoch 00027: val_loss improved from 0.37356 to 0.37226, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 837us/sample - loss: 0.2479 - mean_absolute_error: 0.5473 - val_loss: 0.3723 - val_mean_absolute_error: 0.7131
# Epoch 28/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2470 - mean_absolute_error: 0.5459
# Epoch 00028: val_loss did not improve from 0.37226
# 67191/67191 [==============================] - 56s 832us/sample - loss: 0.2470 - mean_absolute_error: 0.5459 - val_loss: 0.3730 - val_mean_absolute_error: 0.7136
# Epoch 29/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2480 - mean_absolute_error: 0.5472
# Epoch 00029: val_loss did not improve from 0.37226
# 67191/67191 [==============================] - 56s 834us/sample - loss: 0.2479 - mean_absolute_error: 0.5472 - val_loss: 0.3729 - val_mean_absolute_error: 0.7137
# Epoch 30/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2473 - mean_absolute_error: 0.5464
# Epoch 00030: val_loss did not improve from 0.37226
# 67191/67191 [==============================] - 57s 855us/sample - loss: 0.2474 - mean_absolute_error: 0.5465 - val_loss: 0.3740 - val_mean_absolute_error: 0.7149
# Epoch 31/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2458 - mean_absolute_error: 0.5443
# Epoch 00031: val_loss did not improve from 0.37226
# 67191/67191 [==============================] - 56s 834us/sample - loss: 0.2458 - mean_absolute_error: 0.5443 - val_loss: 0.3742 - val_mean_absolute_error: 0.7149
# Epoch 32/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2458 - mean_absolute_error: 0.5442
# Epoch 00032: val_loss did not improve from 0.37226
# 67191/67191 [==============================] - 56s 832us/sample - loss: 0.2458 - mean_absolute_error: 0.5442 - val_loss: 0.3726 - val_mean_absolute_error: 0.7131
# Epoch 33/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2449 - mean_absolute_error: 0.5426
# Epoch 00033: val_loss improved from 0.37226 to 0.37179, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 837us/sample - loss: 0.2450 - mean_absolute_error: 0.5426 - val_loss: 0.3718 - val_mean_absolute_error: 0.7121
# Epoch 34/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2452 - mean_absolute_error: 0.5430
# Epoch 00034: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 832us/sample - loss: 0.2452 - mean_absolute_error: 0.5429 - val_loss: 0.3738 - val_mean_absolute_error: 0.7144
# Epoch 35/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2452 - mean_absolute_error: 0.5430
# Epoch 00035: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 834us/sample - loss: 0.2452 - mean_absolute_error: 0.5430 - val_loss: 0.3725 - val_mean_absolute_error: 0.7126
# Epoch 36/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2447 - mean_absolute_error: 0.5421
# Epoch 00036: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 834us/sample - loss: 0.2447 - mean_absolute_error: 0.5421 - val_loss: 0.3727 - val_mean_absolute_error: 0.7126
# Epoch 37/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2442 - mean_absolute_error: 0.5412
# Epoch 00037: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 57s 854us/sample - loss: 0.2442 - mean_absolute_error: 0.5412 - val_loss: 0.3720 - val_mean_absolute_error: 0.7121
# Epoch 38/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2437 - mean_absolute_error: 0.5403
# Epoch 00038: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 834us/sample - loss: 0.2437 - mean_absolute_error: 0.5403 - val_loss: 0.3729 - val_mean_absolute_error: 0.7129
# Epoch 39/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2437 - mean_absolute_error: 0.5405
# Epoch 00039: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 831us/sample - loss: 0.2437 - mean_absolute_error: 0.5404 - val_loss: 0.3734 - val_mean_absolute_error: 0.7135
# Epoch 40/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2438 - mean_absolute_error: 0.5406
# Epoch 00040: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 837us/sample - loss: 0.2439 - mean_absolute_error: 0.5407 - val_loss: 0.3752 - val_mean_absolute_error: 0.7157
# Epoch 41/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2427 - mean_absolute_error: 0.5388
# Epoch 00041: val_loss did not improve from 0.37179
# 67191/67191 [==============================] - 56s 836us/sample - loss: 0.2428 - mean_absolute_error: 0.5389 - val_loss: 0.3722 - val_mean_absolute_error: 0.7120
# Epoch 42/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2418 - mean_absolute_error: 0.5377
# Epoch 00042: val_loss improved from 0.37179 to 0.37140, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 836us/sample - loss: 0.2418 - mean_absolute_error: 0.5376 - val_loss: 0.3714 - val_mean_absolute_error: 0.7108
# Epoch 43/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2417 - mean_absolute_error: 0.5373
# Epoch 00043: val_loss improved from 0.37140 to 0.37070, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-tanh-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 56s 839us/sample - loss: 0.2418 - mean_absolute_error: 0.5374 - val_loss: 0.3707 - val_mean_absolute_error: 0.7100
# Epoch 44/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2420 - mean_absolute_error: 0.5377
# Epoch 00044: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 56s 834us/sample - loss: 0.2419 - mean_absolute_error: 0.5377 - val_loss: 0.3720 - val_mean_absolute_error: 0.7113
# Epoch 45/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2431 - mean_absolute_error: 0.5394
# Epoch 00045: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 56s 838us/sample - loss: 0.2431 - mean_absolute_error: 0.5394 - val_loss: 0.3726 - val_mean_absolute_error: 0.7125
# Epoch 46/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2430 - mean_absolute_error: 0.5393
# Epoch 00046: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 56s 835us/sample - loss: 0.2430 - mean_absolute_error: 0.5392 - val_loss: 0.3723 - val_mean_absolute_error: 0.7112
# Epoch 47/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2421 - mean_absolute_error: 0.5378
# Epoch 00047: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 60s 895us/sample - loss: 0.2421 - mean_absolute_error: 0.5378 - val_loss: 0.3747 - val_mean_absolute_error: 0.7147
# Epoch 48/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2424 - mean_absolute_error: 0.5383
# Epoch 00048: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 57s 849us/sample - loss: 0.2424 - mean_absolute_error: 0.5383 - val_loss: 0.3727 - val_mean_absolute_error: 0.7122
# Epoch 49/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2418 - mean_absolute_error: 0.5373
# Epoch 00049: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 56s 839us/sample - loss: 0.2418 - mean_absolute_error: 0.5373 - val_loss: 0.3725 - val_mean_absolute_error: 0.7129
# Epoch 50/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2419 - mean_absolute_error: 0.5375
# Epoch 00050: val_loss did not improve from 0.37070
# 67191/67191 [==============================] - 56s 835us/sample - loss: 0.2419 - mean_absolute_error: 0.5375 - val_loss: 0.3722 - val_mean_absolute_error: 0.7119
