# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

window_size = 30

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = (window_size * 8) - 8
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
items = ["close", "ema", "high", "low", "open", "rsi", "sma", "volume"]
day_counts = [f"_{i}" for i in range(0, window_size -1)]
FEATURE_COLUMNS = []
for day_count in day_counts:
    for item in items:
        FEATURE_COLUMNS.append(f"{item}{day_count}")

TARGET_COLUMNS = []
for item in ["close", "high", "low", "open"]:
    TARGET_COLUMNS.append(f"{item}_{window_size - 1}")

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "linear"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{window_size}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv(f"../data/processed/all_processed_{window_size}.csv")

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 66897 samples, validate on 28671 samples
# Epoch 1/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.4322 - mean_absolute_error: 0.7909
# Epoch 00001: val_loss improved from inf to 0.41256, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 40s 596us/sample - loss: 0.4321 - mean_absolute_error: 0.7909 - val_loss: 0.4126 - val_mean_absolute_error: 0.7688
# Epoch 2/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.4088 - mean_absolute_error: 0.7623
# Epoch 00002: val_loss improved from 0.41256 to 0.39884, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 34s 511us/sample - loss: 0.4088 - mean_absolute_error: 0.7623 - val_loss: 0.3988 - val_mean_absolute_error: 0.7518
# Epoch 3/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.3818 - mean_absolute_error: 0.7288
# Epoch 00003: val_loss improved from 0.39884 to 0.38826, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 34s 511us/sample - loss: 0.3818 - mean_absolute_error: 0.7288 - val_loss: 0.3883 - val_mean_absolute_error: 0.7388
# Epoch 4/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.3534 - mean_absolute_error: 0.6934
# Epoch 00004: val_loss improved from 0.38826 to 0.36900, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 497us/sample - loss: 0.3534 - mean_absolute_error: 0.6934 - val_loss: 0.3690 - val_mean_absolute_error: 0.7146
# Epoch 5/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.3210 - mean_absolute_error: 0.6525
# Epoch 00005: val_loss improved from 0.36900 to 0.36154, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 497us/sample - loss: 0.3210 - mean_absolute_error: 0.6525 - val_loss: 0.3615 - val_mean_absolute_error: 0.7049
# Epoch 6/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2930 - mean_absolute_error: 0.6166
# Epoch 00006: val_loss improved from 0.36154 to 0.35099, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 496us/sample - loss: 0.2930 - mean_absolute_error: 0.6166 - val_loss: 0.3510 - val_mean_absolute_error: 0.6911
# Epoch 7/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2683 - mean_absolute_error: 0.5846
# Epoch 00007: val_loss improved from 0.35099 to 0.34077, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 495us/sample - loss: 0.2683 - mean_absolute_error: 0.5846 - val_loss: 0.3408 - val_mean_absolute_error: 0.6782
# Epoch 8/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2487 - mean_absolute_error: 0.5585
# Epoch 00008: val_loss improved from 0.34077 to 0.33673, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 497us/sample - loss: 0.2487 - mean_absolute_error: 0.5585 - val_loss: 0.3367 - val_mean_absolute_error: 0.6730
# Epoch 9/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.2339 - mean_absolute_error: 0.5386
# Epoch 00009: val_loss improved from 0.33673 to 0.33611, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 500us/sample - loss: 0.2339 - mean_absolute_error: 0.5386 - val_loss: 0.3361 - val_mean_absolute_error: 0.6723
# Epoch 10/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2238 - mean_absolute_error: 0.5252
# Epoch 00010: val_loss did not improve from 0.33611
# 66897/66897 [==============================] - 33s 488us/sample - loss: 0.2238 - mean_absolute_error: 0.5252 - val_loss: 0.3365 - val_mean_absolute_error: 0.6714
# Epoch 11/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2147 - mean_absolute_error: 0.5124
# Epoch 00011: val_loss improved from 0.33611 to 0.33480, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 32s 480us/sample - loss: 0.2147 - mean_absolute_error: 0.5124 - val_loss: 0.3348 - val_mean_absolute_error: 0.6694
# Epoch 12/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2089 - mean_absolute_error: 0.5046
# Epoch 00012: val_loss improved from 0.33480 to 0.33323, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 33s 488us/sample - loss: 0.2089 - mean_absolute_error: 0.5046 - val_loss: 0.3332 - val_mean_absolute_error: 0.6670
# Epoch 13/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2036 - mean_absolute_error: 0.4968
# Epoch 00013: val_loss improved from 0.33323 to 0.33020, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 32s 476us/sample - loss: 0.2036 - mean_absolute_error: 0.4968 - val_loss: 0.3302 - val_mean_absolute_error: 0.6634
# Epoch 14/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.2002 - mean_absolute_error: 0.4919
# Epoch 00014: val_loss did not improve from 0.33020
# 66897/66897 [==============================] - 32s 473us/sample - loss: 0.2001 - mean_absolute_error: 0.4919 - val_loss: 0.3308 - val_mean_absolute_error: 0.6640
# Epoch 15/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1974 - mean_absolute_error: 0.4877
# Epoch 00015: val_loss improved from 0.33020 to 0.32772, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 32s 478us/sample - loss: 0.1974 - mean_absolute_error: 0.4877 - val_loss: 0.3277 - val_mean_absolute_error: 0.6600
# Epoch 16/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1947 - mean_absolute_error: 0.4838
# Epoch 00016: val_loss did not improve from 0.32772
# 66897/66897 [==============================] - 32s 473us/sample - loss: 0.1947 - mean_absolute_error: 0.4838 - val_loss: 0.3278 - val_mean_absolute_error: 0.6598
# Epoch 17/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1909 - mean_absolute_error: 0.4786
# Epoch 00017: val_loss improved from 0.32772 to 0.32559, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 32s 475us/sample - loss: 0.1909 - mean_absolute_error: 0.4786 - val_loss: 0.3256 - val_mean_absolute_error: 0.6566
# Epoch 18/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1900 - mean_absolute_error: 0.4774
# Epoch 00018: val_loss did not improve from 0.32559
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1900 - mean_absolute_error: 0.4774 - val_loss: 0.3299 - val_mean_absolute_error: 0.6616
# Epoch 19/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1900 - mean_absolute_error: 0.4766
# Epoch 00019: val_loss did not improve from 0.32559
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1900 - mean_absolute_error: 0.4766 - val_loss: 0.3257 - val_mean_absolute_error: 0.6571
# Epoch 20/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1872 - mean_absolute_error: 0.4734
# Epoch 00020: val_loss did not improve from 0.32559
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1872 - mean_absolute_error: 0.4734 - val_loss: 0.3280 - val_mean_absolute_error: 0.6588
# Epoch 21/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1873 - mean_absolute_error: 0.4727
# Epoch 00021: val_loss did not improve from 0.32559
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1873 - mean_absolute_error: 0.4727 - val_loss: 0.3263 - val_mean_absolute_error: 0.6575
# Epoch 22/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1807 - mean_absolute_error: 0.4642
# Epoch 00022: val_loss improved from 0.32559 to 0.32276, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 32s 477us/sample - loss: 0.1807 - mean_absolute_error: 0.4642 - val_loss: 0.3228 - val_mean_absolute_error: 0.6528
# Epoch 23/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1794 - mean_absolute_error: 0.4619
# Epoch 00023: val_loss did not improve from 0.32276
# 66897/66897 [==============================] - 32s 473us/sample - loss: 0.1795 - mean_absolute_error: 0.4620 - val_loss: 0.3256 - val_mean_absolute_error: 0.6558
# Epoch 24/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1803 - mean_absolute_error: 0.4631
# Epoch 00024: val_loss did not improve from 0.32276
# 66897/66897 [==============================] - 32s 471us/sample - loss: 0.1803 - mean_absolute_error: 0.4631 - val_loss: 0.3247 - val_mean_absolute_error: 0.6552
# Epoch 25/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1817 - mean_absolute_error: 0.4647
# Epoch 00025: val_loss did not improve from 0.32276
# 66897/66897 [==============================] - 31s 471us/sample - loss: 0.1817 - mean_absolute_error: 0.4647 - val_loss: 0.3284 - val_mean_absolute_error: 0.6597
# Epoch 26/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1799 - mean_absolute_error: 0.4627
# Epoch 00026: val_loss did not improve from 0.32276
# 66897/66897 [==============================] - 32s 471us/sample - loss: 0.1799 - mean_absolute_error: 0.4627 - val_loss: 0.3257 - val_mean_absolute_error: 0.6568
# Epoch 27/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1804 - mean_absolute_error: 0.4627
# Epoch 00027: val_loss did not improve from 0.32276
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1804 - mean_absolute_error: 0.4627 - val_loss: 0.3257 - val_mean_absolute_error: 0.6566
# Epoch 28/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1781 - mean_absolute_error: 0.4598
# Epoch 00028: val_loss improved from 0.32276 to 0.32230, saving model to results\2021-12-02_MIXED-30-huber_loss-adam-LSTM-linear-layers-3-units-1000-b.h5
# 66897/66897 [==============================] - 32s 476us/sample - loss: 0.1781 - mean_absolute_error: 0.4598 - val_loss: 0.3223 - val_mean_absolute_error: 0.6526
# Epoch 29/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1763 - mean_absolute_error: 0.4565
# Epoch 00029: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1763 - mean_absolute_error: 0.4565 - val_loss: 0.3244 - val_mean_absolute_error: 0.6544
# Epoch 30/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1760 - mean_absolute_error: 0.4563
# Epoch 00030: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 473us/sample - loss: 0.1760 - mean_absolute_error: 0.4564 - val_loss: 0.3271 - val_mean_absolute_error: 0.6575
# Epoch 31/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1747 - mean_absolute_error: 0.4556
# Epoch 00031: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1747 - mean_absolute_error: 0.4556 - val_loss: 0.3241 - val_mean_absolute_error: 0.6545
# Epoch 32/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1743 - mean_absolute_error: 0.4543
# Epoch 00032: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 473us/sample - loss: 0.1742 - mean_absolute_error: 0.4543 - val_loss: 0.3252 - val_mean_absolute_error: 0.6555
# Epoch 33/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1727 - mean_absolute_error: 0.4518
# Epoch 00033: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1727 - mean_absolute_error: 0.4518 - val_loss: 0.3238 - val_mean_absolute_error: 0.6531
# Epoch 34/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1724 - mean_absolute_error: 0.4516
# Epoch 00034: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1724 - mean_absolute_error: 0.4515 - val_loss: 0.3239 - val_mean_absolute_error: 0.6532
# Epoch 35/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1727 - mean_absolute_error: 0.4522
# Epoch 00035: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 471us/sample - loss: 0.1727 - mean_absolute_error: 0.4522 - val_loss: 0.3253 - val_mean_absolute_error: 0.6551
# Epoch 36/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1723 - mean_absolute_error: 0.4515
# Epoch 00036: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 474us/sample - loss: 0.1723 - mean_absolute_error: 0.4515 - val_loss: 0.3232 - val_mean_absolute_error: 0.6528
# Epoch 37/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1734 - mean_absolute_error: 0.4526
# Epoch 00037: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1734 - mean_absolute_error: 0.4526 - val_loss: 0.3234 - val_mean_absolute_error: 0.6527
# Epoch 38/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1719 - mean_absolute_error: 0.4507
# Epoch 00038: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 31s 470us/sample - loss: 0.1719 - mean_absolute_error: 0.4507 - val_loss: 0.3242 - val_mean_absolute_error: 0.6534
# Epoch 39/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1718 - mean_absolute_error: 0.4503
# Epoch 00039: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1718 - mean_absolute_error: 0.4502 - val_loss: 0.3265 - val_mean_absolute_error: 0.6569
# Epoch 40/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1717 - mean_absolute_error: 0.4505
# Epoch 00040: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 472us/sample - loss: 0.1717 - mean_absolute_error: 0.4505 - val_loss: 0.3236 - val_mean_absolute_error: 0.6530
# Epoch 41/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1704 - mean_absolute_error: 0.4481
# Epoch 00041: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 32s 473us/sample - loss: 0.1704 - mean_absolute_error: 0.4480 - val_loss: 0.3264 - val_mean_absolute_error: 0.6568
# Epoch 42/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1696 - mean_absolute_error: 0.4474
# Epoch 00042: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 33s 486us/sample - loss: 0.1696 - mean_absolute_error: 0.4473 - val_loss: 0.3240 - val_mean_absolute_error: 0.6535
# Epoch 43/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1695 - mean_absolute_error: 0.4471
# Epoch 00043: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 33s 497us/sample - loss: 0.1695 - mean_absolute_error: 0.4471 - val_loss: 0.3243 - val_mean_absolute_error: 0.6538
# Epoch 44/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1697 - mean_absolute_error: 0.4473
# Epoch 00044: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 33s 491us/sample - loss: 0.1697 - mean_absolute_error: 0.4473 - val_loss: 0.3252 - val_mean_absolute_error: 0.6550
# Epoch 45/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1692 - mean_absolute_error: 0.4465
# Epoch 00045: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 35s 527us/sample - loss: 0.1692 - mean_absolute_error: 0.4465 - val_loss: 0.3241 - val_mean_absolute_error: 0.6532
# Epoch 46/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1687 - mean_absolute_error: 0.4459
# Epoch 00046: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 34s 511us/sample - loss: 0.1687 - mean_absolute_error: 0.4459 - val_loss: 0.3240 - val_mean_absolute_error: 0.6533
# Epoch 47/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1684 - mean_absolute_error: 0.4452
# Epoch 00047: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 34s 507us/sample - loss: 0.1684 - mean_absolute_error: 0.4452 - val_loss: 0.3247 - val_mean_absolute_error: 0.6544
# Epoch 48/50
# 66816/66897 [============================>.] - ETA: 0s - loss: 0.1687 - mean_absolute_error: 0.4457
# Epoch 00048: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 34s 510us/sample - loss: 0.1686 - mean_absolute_error: 0.4457 - val_loss: 0.3227 - val_mean_absolute_error: 0.6516
# Epoch 49/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1683 - mean_absolute_error: 0.4452
# Epoch 00049: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 34s 505us/sample - loss: 0.1684 - mean_absolute_error: 0.4452 - val_loss: 0.3232 - val_mean_absolute_error: 0.6519
# Epoch 50/50
# 66880/66897 [============================>.] - ETA: 0s - loss: 0.1680 - mean_absolute_error: 0.4449
# Epoch 00050: val_loss did not improve from 0.32230
# 66897/66897 [==============================] - 33s 499us/sample - loss: 0.1680 - mean_absolute_error: 0.4449 - val_loss: 0.3244 - val_mean_absolute_error: 0.6537
