# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

import multiprocessing
    
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
    
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
tf.keras.mixed_precision.experimental.set_policy(policy)

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False,layer_activation="linear"):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation=layer_activation))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
#def run_tensorflow():

# create these folders if they does not exist
# Window size or the sequence length
N_STEPS = 152
# Lookup step, 1 is the next day
#LOOKUP_STEP = int(run_dict[run]["LOOKUP_STEP"])

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
FEATURE_COLUMNS = ["close_0","ema_0","high_0","low_0","open_0","rsi_0","sma_0","volume_0","close_1","ema_1","high_1","low_1","open_1","rsi_1","sma_1","volume_1",
                   "close_2","ema_2","high_2","low_2","open_2","rsi_2","sma_2","volume_2","close_3","ema_3","high_3","low_3","open_3","rsi_3","sma_3","volume_3",
                   "close_4","ema_4","high_4","low_4","open_4","rsi_4","sma_4","volume_4","close_5","ema_5","high_5","low_5","open_5","rsi_5","sma_5","volume_5",
                   "close_6","ema_6","high_6","low_6","open_6","rsi_6","sma_6","volume_6","close_7","ema_7","high_7","low_7","open_7","rsi_7","sma_7","volume_7",
                   "close_8","ema_8","high_8","low_8","open_8","rsi_8","sma_8","volume_8","close_9","ema_9","high_9","low_9","open_9","rsi_9","sma_9","volume_9",
                   "close_10","ema_10","high_10","low_10","open_10","rsi_10","sma_10","volume_10","close_11","ema_11","high_11","low_11","open_11","rsi_11","sma_11","volume_11",
                   "close_12","ema_12","high_12","low_12","open_12","rsi_12","sma_12","volume_12","close_13","ema_13","high_13","low_13","open_13","rsi_13","sma_13","volume_13",
                   "close_14","ema_14","high_14","low_14","open_14","rsi_14","sma_14","volume_14","close_15","ema_15","high_15","low_15","open_15","rsi_15","sma_15","volume_15",
                   "close_16","ema_16","high_16","low_16","open_16","rsi_16","sma_16","volume_16","close_17","ema_17","high_17","low_17","open_17","rsi_17","sma_17","volume_17",
                   "close_18","ema_18","high_18","low_18","open_18","rsi_18","sma_18","volume_18"]
TARGET_COLUMNS = ["close_19","high_19","low_19","open_19"]
# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters

N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 1000
# 40% dropout
DROPOUT = 0.25
# whether to use bidirectional RNNs
BIDIRECTIONAL = True

### training parameters

# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 50

LAYER_ACTIVATION = "elu"

# Stock market
ticker = "MIXED"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-{LAYER_ACTIVATION}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#
#----------------------------------------------------------------------------------------------------------#

#try:
if not os.path.isdir("results"):
    os.mkdir("results")

if not os.path.isdir("logs"):
    os.mkdir("logs")

if not os.path.isdir("data"):
    os.mkdir("data")

# load the data
data = pd.read_csv('../data/processed/all_processed_20.csv')

# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL, layer_activation=LAYER_ACTIVATION)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

X = data[FEATURE_COLUMNS]
y = data[TARGET_COLUMNS]

# convert to numpy arrays
X = np.array(X)
y = np.array(y)

# reshape X to fit the neural network
X = X.reshape((X.shape[0], 1, X.shape[1]))

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True)

history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)

model.save(os.path.join("results", model_name) + ".h5")

#except:
#    print("There was an attempt.")
tf.keras.backend.clear_session()
# Out:
# Train on 67191 samples, validate on 28797 samples
# Epoch 1/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4498 - mean_absolute_error: 0.8124
# Epoch 00001: val_loss improved from inf to 0.44288, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 41s 608us/sample - loss: 0.4498 - mean_absolute_error: 0.8123 - val_loss: 0.4429 - val_mean_absolute_error: 0.8035
# Epoch 2/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.4341 - mean_absolute_error: 0.7933
# Epoch 00002: val_loss improved from 0.44288 to 0.44233, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 506us/sample - loss: 0.4340 - mean_absolute_error: 0.7932 - val_loss: 0.4423 - val_mean_absolute_error: 0.8030
# Epoch 3/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4215 - mean_absolute_error: 0.7778
# Epoch 00003: val_loss improved from 0.44233 to 0.42687, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 33s 497us/sample - loss: 0.4215 - mean_absolute_error: 0.7777 - val_loss: 0.4269 - val_mean_absolute_error: 0.7841
# Epoch 4/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.4031 - mean_absolute_error: 0.7551
# Epoch 00004: val_loss improved from 0.42687 to 0.41902, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 35s 515us/sample - loss: 0.4031 - mean_absolute_error: 0.7551 - val_loss: 0.4190 - val_mean_absolute_error: 0.7737
# Epoch 5/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.3808 - mean_absolute_error: 0.7266
# Epoch 00005: val_loss improved from 0.41902 to 0.40612, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 35s 517us/sample - loss: 0.3807 - mean_absolute_error: 0.7264 - val_loss: 0.4061 - val_mean_absolute_error: 0.7574
# Epoch 6/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3563 - mean_absolute_error: 0.6957
# Epoch 00006: val_loss improved from 0.40612 to 0.39943, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 509us/sample - loss: 0.3563 - mean_absolute_error: 0.6957 - val_loss: 0.3994 - val_mean_absolute_error: 0.7491
# Epoch 7/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.3311 - mean_absolute_error: 0.6639
# Epoch 00007: val_loss improved from 0.39943 to 0.39235, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 511us/sample - loss: 0.3312 - mean_absolute_error: 0.6640 - val_loss: 0.3924 - val_mean_absolute_error: 0.7397
# Epoch 8/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.3085 - mean_absolute_error: 0.6345
# Epoch 00008: val_loss improved from 0.39235 to 0.39007, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 511us/sample - loss: 0.3085 - mean_absolute_error: 0.6345 - val_loss: 0.3901 - val_mean_absolute_error: 0.7364
# Epoch 9/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2905 - mean_absolute_error: 0.6108
# Epoch 00009: val_loss improved from 0.39007 to 0.38726, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 509us/sample - loss: 0.2905 - mean_absolute_error: 0.6108 - val_loss: 0.3873 - val_mean_absolute_error: 0.7330
# Epoch 10/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2764 - mean_absolute_error: 0.5919
# Epoch 00010: val_loss improved from 0.38726 to 0.38442, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 511us/sample - loss: 0.2764 - mean_absolute_error: 0.5918 - val_loss: 0.3844 - val_mean_absolute_error: 0.7289
# Epoch 11/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2653 - mean_absolute_error: 0.5774
# Epoch 00011: val_loss improved from 0.38442 to 0.38344, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 35s 515us/sample - loss: 0.2653 - mean_absolute_error: 0.5774 - val_loss: 0.3834 - val_mean_absolute_error: 0.7275
# Epoch 12/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2564 - mean_absolute_error: 0.5649
# Epoch 00012: val_loss improved from 0.38344 to 0.38343, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 512us/sample - loss: 0.2563 - mean_absolute_error: 0.5648 - val_loss: 0.3834 - val_mean_absolute_error: 0.7273
# Epoch 13/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2512 - mean_absolute_error: 0.5580
# Epoch 00013: val_loss improved from 0.38343 to 0.37977, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 513us/sample - loss: 0.2512 - mean_absolute_error: 0.5580 - val_loss: 0.3798 - val_mean_absolute_error: 0.7229
# Epoch 14/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2459 - mean_absolute_error: 0.5506
# Epoch 00014: val_loss improved from 0.37977 to 0.37728, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 513us/sample - loss: 0.2459 - mean_absolute_error: 0.5507 - val_loss: 0.3773 - val_mean_absolute_error: 0.7194
# Epoch 15/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2412 - mean_absolute_error: 0.5434
# Epoch 00015: val_loss did not improve from 0.37728
# 67191/67191 [==============================] - 34s 513us/sample - loss: 0.2413 - mean_absolute_error: 0.5435 - val_loss: 0.3778 - val_mean_absolute_error: 0.7196
# Epoch 16/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2385 - mean_absolute_error: 0.5396
# Epoch 00016: val_loss improved from 0.37728 to 0.37595, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 503us/sample - loss: 0.2385 - mean_absolute_error: 0.5396 - val_loss: 0.3759 - val_mean_absolute_error: 0.7175
# Epoch 17/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2362 - mean_absolute_error: 0.5365
# Epoch 00017: val_loss improved from 0.37595 to 0.37581, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 33s 497us/sample - loss: 0.2362 - mean_absolute_error: 0.5365 - val_loss: 0.3758 - val_mean_absolute_error: 0.7170
# Epoch 18/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2346 - mean_absolute_error: 0.5341
# Epoch 00018: val_loss improved from 0.37581 to 0.37474, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 500us/sample - loss: 0.2346 - mean_absolute_error: 0.5341 - val_loss: 0.3747 - val_mean_absolute_error: 0.7159
# Epoch 19/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2317 - mean_absolute_error: 0.5296
# Epoch 00019: val_loss improved from 0.37474 to 0.37303, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 506us/sample - loss: 0.2317 - mean_absolute_error: 0.5296 - val_loss: 0.3730 - val_mean_absolute_error: 0.7131
# Epoch 20/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2301 - mean_absolute_error: 0.5273
# Epoch 00020: val_loss improved from 0.37303 to 0.37103, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 501us/sample - loss: 0.2301 - mean_absolute_error: 0.5273 - val_loss: 0.3710 - val_mean_absolute_error: 0.7105
# Epoch 21/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2289 - mean_absolute_error: 0.5254
# Epoch 00021: val_loss did not improve from 0.37103
# 67191/67191 [==============================] - 34s 499us/sample - loss: 0.2289 - mean_absolute_error: 0.5254 - val_loss: 0.3716 - val_mean_absolute_error: 0.7117
# Epoch 22/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2274 - mean_absolute_error: 0.5230
# Epoch 00022: val_loss improved from 0.37103 to 0.36982, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 504us/sample - loss: 0.2274 - mean_absolute_error: 0.5231 - val_loss: 0.3698 - val_mean_absolute_error: 0.7084
# Epoch 23/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2269 - mean_absolute_error: 0.5220
# Epoch 00023: val_loss did not improve from 0.36982
# 67191/67191 [==============================] - 33s 497us/sample - loss: 0.2269 - mean_absolute_error: 0.5220 - val_loss: 0.3700 - val_mean_absolute_error: 0.7093
# Epoch 24/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2254 - mean_absolute_error: 0.5198
# Epoch 00024: val_loss improved from 0.36982 to 0.36902, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 506us/sample - loss: 0.2254 - mean_absolute_error: 0.5198 - val_loss: 0.3690 - val_mean_absolute_error: 0.7076
# Epoch 25/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2245 - mean_absolute_error: 0.5186
# Epoch 00025: val_loss did not improve from 0.36902
# 67191/67191 [==============================] - 34s 502us/sample - loss: 0.2245 - mean_absolute_error: 0.5186 - val_loss: 0.3695 - val_mean_absolute_error: 0.7080
# Epoch 26/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2241 - mean_absolute_error: 0.5177
# Epoch 00026: val_loss did not improve from 0.36902
# 67191/67191 [==============================] - 33s 497us/sample - loss: 0.2241 - mean_absolute_error: 0.5177 - val_loss: 0.3697 - val_mean_absolute_error: 0.7087
# Epoch 27/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2228 - mean_absolute_error: 0.5158
# Epoch 00027: val_loss did not improve from 0.36902
# 67191/67191 [==============================] - 33s 495us/sample - loss: 0.2229 - mean_absolute_error: 0.5159 - val_loss: 0.3726 - val_mean_absolute_error: 0.7122
# Epoch 28/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2230 - mean_absolute_error: 0.5162
# Epoch 00028: val_loss improved from 0.36902 to 0.36894, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 33s 498us/sample - loss: 0.2230 - mean_absolute_error: 0.5162 - val_loss: 0.3689 - val_mean_absolute_error: 0.7075
# Epoch 29/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2218 - mean_absolute_error: 0.5143
# Epoch 00029: val_loss did not improve from 0.36894
# 67191/67191 [==============================] - 33s 497us/sample - loss: 0.2218 - mean_absolute_error: 0.5142 - val_loss: 0.3706 - val_mean_absolute_error: 0.7092
# Epoch 30/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2215 - mean_absolute_error: 0.5140
# Epoch 00030: val_loss did not improve from 0.36894
# 67191/67191 [==============================] - 33s 497us/sample - loss: 0.2215 - mean_absolute_error: 0.5141 - val_loss: 0.3704 - val_mean_absolute_error: 0.7091
# Epoch 31/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2203 - mean_absolute_error: 0.5120
# Epoch 00031: val_loss improved from 0.36894 to 0.36836, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 34s 499us/sample - loss: 0.2203 - mean_absolute_error: 0.5120 - val_loss: 0.3684 - val_mean_absolute_error: 0.7067
# Epoch 32/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2206 - mean_absolute_error: 0.5124
# Epoch 00032: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 36s 530us/sample - loss: 0.2206 - mean_absolute_error: 0.5125 - val_loss: 0.3703 - val_mean_absolute_error: 0.7096
# Epoch 33/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2201 - mean_absolute_error: 0.5118
# Epoch 00033: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 38s 564us/sample - loss: 0.2202 - mean_absolute_error: 0.5119 - val_loss: 0.3687 - val_mean_absolute_error: 0.7071
# Epoch 34/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2195 - mean_absolute_error: 0.5108
# Epoch 00034: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 36s 539us/sample - loss: 0.2194 - mean_absolute_error: 0.5107 - val_loss: 0.3690 - val_mean_absolute_error: 0.7078
# Epoch 35/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2191 - mean_absolute_error: 0.5101
# Epoch 00035: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 34s 511us/sample - loss: 0.2190 - mean_absolute_error: 0.5101 - val_loss: 0.3684 - val_mean_absolute_error: 0.7069
# Epoch 36/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2186 - mean_absolute_error: 0.5096
# Epoch 00036: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 35s 524us/sample - loss: 0.2187 - mean_absolute_error: 0.5097 - val_loss: 0.3690 - val_mean_absolute_error: 0.7078
# Epoch 37/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2182 - mean_absolute_error: 0.5084
# Epoch 00037: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 35s 524us/sample - loss: 0.2181 - mean_absolute_error: 0.5083 - val_loss: 0.3696 - val_mean_absolute_error: 0.7087
# Epoch 38/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2183 - mean_absolute_error: 0.5087
# Epoch 00038: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 35s 523us/sample - loss: 0.2184 - mean_absolute_error: 0.5087 - val_loss: 0.3691 - val_mean_absolute_error: 0.7076
# Epoch 39/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2178 - mean_absolute_error: 0.5078
# Epoch 00039: val_loss did not improve from 0.36836
# 67191/67191 [==============================] - 35s 521us/sample - loss: 0.2177 - mean_absolute_error: 0.5077 - val_loss: 0.3690 - val_mean_absolute_error: 0.7075
# Epoch 40/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2170 - mean_absolute_error: 0.5066
# Epoch 00040: val_loss improved from 0.36836 to 0.36797, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 35s 526us/sample - loss: 0.2170 - mean_absolute_error: 0.5065 - val_loss: 0.3680 - val_mean_absolute_error: 0.7061
# Epoch 41/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2165 - mean_absolute_error: 0.5060
# Epoch 00041: val_loss did not improve from 0.36797
# 67191/67191 [==============================] - 35s 526us/sample - loss: 0.2166 - mean_absolute_error: 0.5060 - val_loss: 0.3687 - val_mean_absolute_error: 0.7067
# Epoch 42/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2169 - mean_absolute_error: 0.5066
# Epoch 00042: val_loss did not improve from 0.36797
# 67191/67191 [==============================] - 35s 519us/sample - loss: 0.2169 - mean_absolute_error: 0.5066 - val_loss: 0.3682 - val_mean_absolute_error: 0.7064
# Epoch 43/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2167 - mean_absolute_error: 0.5062
# Epoch 00043: val_loss improved from 0.36797 to 0.36659, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 36s 534us/sample - loss: 0.2166 - mean_absolute_error: 0.5061 - val_loss: 0.3666 - val_mean_absolute_error: 0.7043
# Epoch 44/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2159 - mean_absolute_error: 0.5049
# Epoch 00044: val_loss did not improve from 0.36659
# 67191/67191 [==============================] - 35s 523us/sample - loss: 0.2160 - mean_absolute_error: 0.5049 - val_loss: 0.3669 - val_mean_absolute_error: 0.7048
# Epoch 45/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2166 - mean_absolute_error: 0.5061
# Epoch 00045: val_loss did not improve from 0.36659
# 67191/67191 [==============================] - 37s 544us/sample - loss: 0.2166 - mean_absolute_error: 0.5061 - val_loss: 0.3678 - val_mean_absolute_error: 0.7055
# Epoch 46/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2158 - mean_absolute_error: 0.5048
# Epoch 00046: val_loss did not improve from 0.36659
# 67191/67191 [==============================] - 36s 530us/sample - loss: 0.2157 - mean_absolute_error: 0.5047 - val_loss: 0.3673 - val_mean_absolute_error: 0.7051
# Epoch 47/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2156 - mean_absolute_error: 0.5045
# Epoch 00047: val_loss improved from 0.36659 to 0.36633, saving model to results\2021-12-02_MIXED-huber_loss-adam-LSTM-elu-layers-3-units-1000-b.h5
# 67191/67191 [==============================] - 35s 525us/sample - loss: 0.2155 - mean_absolute_error: 0.5044 - val_loss: 0.3663 - val_mean_absolute_error: 0.7040
# Epoch 48/50
# 67072/67191 [============================>.] - ETA: 0s - loss: 0.2150 - mean_absolute_error: 0.5033
# Epoch 00048: val_loss did not improve from 0.36633
# 67191/67191 [==============================] - 35s 521us/sample - loss: 0.2149 - mean_absolute_error: 0.5031 - val_loss: 0.3680 - val_mean_absolute_error: 0.7059
# Epoch 49/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2152 - mean_absolute_error: 0.5036
# Epoch 00049: val_loss did not improve from 0.36633
# 67191/67191 [==============================] - 35s 522us/sample - loss: 0.2151 - mean_absolute_error: 0.5035 - val_loss: 0.3669 - val_mean_absolute_error: 0.7047
# Epoch 50/50
# 67136/67191 [============================>.] - ETA: 0s - loss: 0.2152 - mean_absolute_error: 0.5037
# Epoch 00050: val_loss did not improve from 0.36633
# 67191/67191 [==============================] - 35s 521us/sample - loss: 0.2152 - mean_absolute_error: 0.5037 - val_loss: 0.3686 - val_mean_absolute_error: 0.7065
